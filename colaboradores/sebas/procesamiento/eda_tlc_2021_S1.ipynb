# %% [markdown]
# En este archivo haremos un análisis exploratorio preliminar de los viajes de los "High Volume For-Hire Vehicle (HVFHV)" para el __primer semestre__ del año __2021__. Esta categoría empezó a aplicarse en Febrero de 2019 en NYC a vehículos con más de 10000 viajes por día.

# %%
import modin.pandas as pd
from distributed import Client
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# Inicializa un cliente Dask para la ejecución distribuida en múltiples núcleos
client = Client(memory_limit='8GB')

# %%
tlc_21_01 = pd.read_parquet("../raw_data/fhvhv_tripdata_2021-01.parquet")
tlc_21_02 = pd.read_parquet("../raw_data/fhvhv_tripdata_2021-02.parquet")
tlc_21_03 = pd.read_parquet("../raw_data/fhvhv_tripdata_2021-03.parquet")
tlc_21_04 = pd.read_parquet("../raw_data/fhvhv_tripdata_2021-04.parquet")
tlc_21_05 = pd.read_parquet("../raw_data/fhvhv_tripdata_2021-05.parquet")
tlc_21_06 = pd.read_parquet("../raw_data/fhvhv_tripdata_2021-06.parquet")

# %%
# Todos los dataframes del primer semestre de 2021.
tlc_21_S1 = [tlc_21_01, tlc_21_02, tlc_21_03, tlc_21_04, tlc_21_05, tlc_21_06]

# %% [markdown]
# ## Estructura general

# %%
tlc_21_01.dtypes
# Out:
# hvfhs_license_num               object
# dispatching_base_num            object
# originating_base_num            object
# request_datetime        datetime64[ns]
# on_scene_datetime       datetime64[ns]
# pickup_datetime         datetime64[ns]
# dropoff_datetime        datetime64[ns]
# PULocationID                     int64
# DOLocationID                     int64
# trip_miles                     float64
# trip_time                        int64
# base_passenger_fare            float64
# tolls                          float64
# bcf                            float64
# sales_tax                      float64
# congestion_surcharge           float64
# airport_fee                    float64
# tips                           float64
# driver_pay                     float64
# shared_request_flag             object
# shared_match_flag               object
# access_a_ride_flag              object
# wav_request_flag                object
# wav_match_flag                  object
# dtype: object

# %% [markdown]
# Hay 24 columnas:
# * 4 de tipo datetime.
# * 9 de tipo float.
# * 3 de tipo int.
# * 8 de tipo object.

# %%
for df in tlc_21_S1:
    print(f"Filas: {df.shape[0]}")
# Out:
# Filas: 11908468
# Filas: 11613942
# Filas: 14227393
# Filas: 14111371
# Filas: 14719171
# Filas: 14961892

# %%
tlc_21_01.head()
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B02682               B02682
# 1            HV0003               B02682               B02682
# 2            HV0003               B02764               B02764
# 3            HV0003               B02764               B02764
# 4            HV0003               B02764               B02764
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2021-01-01 00:28:09 2021-01-01 00:31:42 2021-01-01 00:33:44
# 1 2021-01-01 00:45:56 2021-01-01 00:55:19 2021-01-01 00:55:19
# 2 2021-01-01 00:21:15 2021-01-01 00:22:41 2021-01-01 00:23:56
# 3 2021-01-01 00:39:12 2021-01-01 00:42:37 2021-01-01 00:42:51
# 4 2021-01-01 00:46:11 2021-01-01 00:47:17 2021-01-01 00:48:14
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  trip_time  \
# 0 2021-01-01 00:49:07           230           166        5.26        923
# 1 2021-01-01 01:18:21           152           167        3.65       1382
# 2 2021-01-01 00:38:05           233           142        3.51        849
# 3 2021-01-01 00:45:50           142           143        0.74        179
# 4 2021-01-01 01:08:42           143            78        9.20       1228
#
#    base_passenger_fare  tolls   bcf  sales_tax  congestion_surcharge  \
# 0                22.28    0.0  0.67       1.98                  2.75
# 1                18.36    0.0  0.55       1.63                  0.00
# 2                14.05    0.0  0.48       1.25                  2.75
# 3                 7.91    0.0  0.24       0.70                  2.75
# 4                27.11    0.0  0.81       2.41                  2.75
#
#    airport_fee  tips  driver_pay shared_request_flag shared_match_flag  \
# 0          NaN  0.00       14.99                   N                 N
# 1          NaN  0.00       17.06                   N                 N
# 2          NaN  0.94       12.98                   N                 N
# 3          NaN  0.00        7.41                   N                 N
# 4          NaN  0.00       22.44                   N                 N
#
#   access_a_ride_flag wav_request_flag wav_match_flag
# 0                                   N              N
# 1                                   N              N
# 2                                   N              N
# 3                                   N              N
# 4                                   N              N

# %% [markdown]
# ## Duplicados

# %% [markdown]
# Vamos a analizar la presencia de duplicados. Al haber tantas columnas, vamos a elegir un subset representativo. En caso de encontrar duplicados aplicaremos distintas estrategias.

# %%
#tlc_21_01.duplicated(subset=["pickup_datetime", "dropoff_datetime", 
#                             "PULocationID", "DOLocationID", "trip_miles"]).sum()
# Out:
# 69

# %% [markdown]
# Hay 69 duplicados en este subset. Evaluemoslo en el conjunto de todas las columnas.

# %%
#tlc_21_01.duplicated().sum()
# Out:
# 26

# %% [markdown]
# Hay 26 duplicados en enero de 2021.

# %%
#tlc_21_02.duplicated(subset=["pickup_datetime", "dropoff_datetime", 
#                             "PULocationID", "DOLocationID", "trip_miles"]).sum()
# Out:
# 1

# %% [markdown]
# Hay 1 duplicado en este subset. Veamoslo en el conjunto de las columnas.

# %%
#tlc_21_02[tlc_21_02.duplicated(subset=["pickup_datetime", "dropoff_datetime", 
#                                       "PULocationID", "DOLocationID", "trip_miles"], 
#                                       keep=False)]
# Out:
#         hvfhs_license_num dispatching_base_num originating_base_num  \
# 7572776            HV0003               B02882               B02882
# 7582773            HV0003               B02875               B02875
#
#            request_datetime   on_scene_datetime     pickup_datetime  \
# 7572776 2021-02-19 20:37:30 2021-02-19 20:44:03 2021-02-19 20:45:39
# 7582773 2021-02-19 20:41:52 2021-02-19 20:45:08 2021-02-19 20:45:39
#
#            dropoff_datetime  PULocationID  DOLocationID  trip_miles  \
# 7572776 2021-02-19 20:52:02           247            42         1.2
# 7582773 2021-02-19 20:52:02           247            42         1.2
#
#          trip_time  base_passenger_fare  tolls   bcf  sales_tax  \
# 7572776        383                11.08    0.0  0.33       0.98
# 7582773        383                 8.49    0.0  0.25       0.75
#
#          congestion_surcharge  airport_fee  tips  driver_pay  \
# 7572776                   0.0          NaN   0.0        5.39
# 7582773                   0.0          NaN   0.0        5.93
#
#         shared_request_flag shared_match_flag access_a_ride_flag  \
# 7572776                   N                 N
# 7582773                   N                 N
#
#         wav_request_flag wav_match_flag
# 7572776                N              N
# 7582773                N              N

# %% [markdown]
# Vemos que difieren en request_datetime por lo que no son duplicados.

# %%
#tlc_21_03.duplicated(subset=["pickup_datetime", "dropoff_datetime", 
#                             "PULocationID", "DOLocationID", "trip_miles"]).sum()
# Out:
# 0

# %%
#tlc_21_04.duplicated(subset=["pickup_datetime", "dropoff_datetime", 
#                             "PULocationID", "DOLocationID", "trip_miles"]).sum()
# Out:
# 77

# %% [markdown]
# Hay 77 duplicados en este subset. Vamos a analizarlo en todo el conjunto de columnas.

# %%
#tlc_21_04.duplicated().sum()
# Out:
# 25

# %% [markdown]
# Hay 25 duplicados en abril de 2021.

# %%
#tlc_21_05.duplicated(subset=["pickup_datetime", "dropoff_datetime", 
#                             "PULocationID", "DOLocationID", "trip_miles"]).sum()
# Out:
# 510

# %% [markdown]
# Hay 510 en este subset, vamos a analizar el conjunto completo.

# %%
#tlc_21_05.duplicated().sum()
# Out:
# 510

# %% [markdown]
# Hay efectivamente 510 duplicados en mayo de 2021.

# %%
#tlc_21_06.duplicated(subset=["pickup_datetime", "dropoff_datetime", 
#                             "PULocationID", "DOLocationID", "trip_miles"]).sum()
# Out:
# 0

# %% [markdown]
# ## hvfhs_license_num

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.hvfhs_license_num.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"Los valores únicos por mes: "
          f"{df.hvfhs_license_num.unique()}")
# Out:
# Los valores únicos por mes: ['HV0003' 'HV0005' 'HV0004']
# Los valores únicos por mes: ['HV0003' 'HV0005' 'HV0004']
# Los valores únicos por mes: ['HV0003' 'HV0005' 'HV0004']
# Los valores únicos por mes: ['HV0003' 'HV0005' 'HV0004']
# Los valores únicos por mes: ['HV0003' 'HV0005' 'HV0004']
# Los valores únicos por mes: ['HV0003' 'HV0005' 'HV0004']

# %%
for df in tlc_21_S1:
    print(df.hvfhs_license_num.value_counts(normalize=True), "\n")
# Out:
# UserWarning: `df.groupby(categorical_by, sort=False)` implementation has mismatches with pandas:
# the groupby keys will be sorted anyway, although the 'sort=False' was passed. See the following issue for more details: https://github.com/modin-project/modin/issues/3571.
# hvfhs_license_num
# HV0003    0.730919
# HV0005    0.259842
# HV0004    0.009238
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.713863
# HV0005    0.278731
# HV0004    0.007406
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.715056
# HV0005    0.277402
# HV0004    0.007543
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.725541
# HV0005    0.267081
# HV0004    0.007378
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.734309
# HV0005    0.259147
# HV0004    0.006544
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.718318
# HV0005    0.276079
# HV0004    0.005604
# Name: proportion, dtype: float64

# %% [markdown]
# Entre el 71-73% de las licencias corresponden a HV0003 (Uber) entre el 25-27% de las licencias corresponden a HV0005 (Lyft) y menos del 1% corresponden a HV0004 (Via).

# %% [markdown]
# ## dispatching_base_num

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.dispatching_base_num.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"Los valores únicos por mes: "
          f"{sorted(df.dispatching_base_num.unique())}")
# Out:
# Los valores únicos por mes: ['B02395', 'B02510', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02800', 'B02835', 'B02836', 'B02844', 'B02864', 'B02865', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02878', 'B02879', 'B02880', 'B02882', 'B02883', 'B02884', 'B02887', 'B02888', 'B02889', 'B03136']
# Los valores únicos por mes: ['B02395', 'B02510', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02800', 'B02835', 'B02836', 'B02844', 'B02864', 'B02865', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02878', 'B02879', 'B02880', 'B02882', 'B02883', 'B02884', 'B02887', 'B02888', 'B02889', 'B03136']
# Los valores únicos por mes: ['B02395', 'B02510', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02800', 'B02835', 'B02836', 'B02844', 'B02864', 'B02865', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02878', 'B02879', 'B02880', 'B02882', 'B02883', 'B02884', 'B02887', 'B02888', 'B02889', 'B03136']
# Los valores únicos por mes: ['B02395', 'B02510', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02800', 'B02835', 'B02836', 'B02844', 'B02864', 'B02865', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02878', 'B02879', 'B02880', 'B02882', 'B02883', 'B02884', 'B02887', 'B02888', 'B02889', 'B03136']
# Los valores únicos por mes: ['B02395', 'B02510', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02800', 'B02835', 'B02836', 'B02844', 'B02864', 'B02865', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02878', 'B02879', 'B02880', 'B02882', 'B02883', 'B02884', 'B02887', 'B02888', 'B02889', 'B03136']
# Los valores únicos por mes: ['B02395', 'B02510', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02800', 'B02835', 'B02836', 'B02844', 'B02864', 'B02865', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02878', 'B02879', 'B02880', 'B02882', 'B02883', 'B02884', 'B02887', 'B02888', 'B02889', 'B03136']

# %% [markdown]
# Cada base está asociada con una compañía distinta.

# %% [markdown]
# ## originating_base_num

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.originating_base_num.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.2692268224594465
# Promedio de nulos por mes: 0.2857885806559048
# Promedio de nulos por mes: 0.28488037126689336
# Promedio de nulos por mes: 0.27418228887894736
# Promedio de nulos por mes: 0.2654380467486926
# Promedio de nulos por mes: 0.2814118027319005

# %% [markdown]
# Hay un promedio de 26-28% de valores faltantes en esta columna.

# %%
for df in tlc_21_S1:
    print(f"Los valores únicos por mes: "
          f"{df.originating_base_num.unique()}")
# Out:
# Los valores únicos por mes: ['B02682' 'B02764' None 'B02875' 'B02835' 'B02836' 'B02512' 'B02872'
#  'B02888' 'B02617' 'B02864' 'B02877' 'B02889' 'B02876' 'B02765' 'B02395'
#  'B02871' 'B02869' 'B02866' 'B02867' 'B02884' 'B02879' 'B02878' 'B02882'
#  'B02865' 'B02883' 'B02880' 'B02887' 'B02870' 'B02510' 'B02800' 'B03136'
#  'B02826' 'B02729' 'B00457' 'B02026' 'B03153' 'B00446' 'B00692' 'B00887']
# Los valores únicos por mes: ['B02764' None 'B02872' 'B02888' 'B02883' 'B02867' 'B02864' 'B02835'
#  'B02869' 'B02878' 'B02836' 'B02617' 'B02879' 'B02765' 'B02870' 'B02866'
#  'B02884' 'B02887' 'B02512' 'B02877' 'B02682' 'B02875' 'B02395' 'B02876'
#  'B02871' 'B02882' 'B02889' 'B02880' 'B02865' 'B02510' 'B02729' 'B00446'
#  'B00457' 'B00887' 'B02800' 'B02026' 'B03136' 'B03153' 'B02826']
# Los valores únicos por mes: ['B02764' 'B02835' 'B02872' 'B02617' None 'B02883' 'B02875' 'B02867'
#  'B02864' 'B02876' 'B02765' 'B02866' 'B02882' 'B02869' 'B02887' 'B02879'
#  'B02877' 'B02871' 'B02682' 'B02865' 'B02836' 'B02878' 'B02888' 'B02512'
#  'B02884' 'B02889' 'B02880' 'B02870' 'B02395' 'B02510' 'B02800' 'B02729'
#  'B00457' 'B03153' 'B03136' 'B00446' 'B00887' 'B02026' 'B00692']
# Los valores únicos por mes: ['B02764' 'B02878' None 'B02884' 'B02617' 'B02872' 'B02510' 'B02512'
#  'B02876' 'B02395' 'B02866' 'B02682' 'B02869' 'B02887' 'B02875' 'B02879'
#  'B02864' 'B02765' 'B02877' 'B02882' 'B02888' 'B02835' 'B02871' 'B02867'
#  'B02836' 'B02865' 'B02883' 'B02880' 'B02870' 'B02889' 'B02800' 'B03136'
#  'B02026' 'B02729' 'B03153' 'B00457' 'B00887' 'B00446']
# Los valores únicos por mes: ['B02764' 'B02875' 'B02878' 'B02836' None 'B02882' 'B02617' 'B02888'
#  'B02883' 'B02864' 'B02872' 'B02867' 'B02835' 'B02876' 'B02866' 'B02869'
#  'B02887' 'B02765' 'B02682' 'B02880' 'B02884' 'B02879' 'B02871' 'B02865'
#  'B02512' 'B02877' 'B02870' 'B02889' 'B02395' 'B02510' 'B02800' 'B03136'
#  'B02729' 'B03153' 'B02026' 'B00887' 'B00446' 'B00457' 'B02826']
# Name: dropoff_datetime, dtype: object
#
# La descripción de cada mes es: count                         14961892
# mean     2021-06-16 01:52:12.528530432
# min                2021-06-01 00:03:05
# 25%      2021-06-08 16:03:58.750000128
# 50%                2021-06-16 01:04:36
# 75%                2021-06-23 16:02:49
# max                2021-07-01 01:58:31
# Name: dropoff_datetime, dtype: object

# %% [markdown]
# No se observan outliers. Los valores extremos se superponen entre meses en algunos casos.

# %% [markdown]
# ## PULocationID

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.PULocationID.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"El número de zonas únicas de cada mes es: "
          f"{df.PULocationID.nunique()}")
# Out:
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 261
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 261
# El número de zonas únicas de cada mes es: 263

# %% [markdown]
# Es la zona de taxi TLC donde inició el viaje. Hay 265 en total.

# %%
for df in tlc_21_S1:
    print(f"Mínimo: {df.PULocationID.min()}, Máximo {df.PULocationID.max()}")
# Out:
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265

# %% [markdown]
# No se observan outliers en esta columna.

# %% [markdown]
# ## DOLocationID

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.DOLocationID.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"El número de zonas únicas de cada mes es: "
          f"{df.DOLocationID.nunique()}")
# Out:
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 261
# El número de zonas únicas de cada mes es: 263
# El número de zonas únicas de cada mes es: 261
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 263

# %% [markdown]
# Es la zona de taxi TLC donde culminó el viaje. Hay 265 en total.

# %%
for df in tlc_21_S1:
    print(f"Mínimo: {df.DOLocationID.min()}, Máximo {df.DOLocationID.max()}")
# Out:
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265

# %% [markdown]
# No se observan outliers en esta columna.

# %% [markdown]
# ## trip_miles

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.trip_miles.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"La descripción de cada mes es: "
          f"{df.trip_miles.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.190847e+07
# mean     4.512293e+00
# std      5.020948e+00
# min      0.000000e+00
# 25%      1.560000e+00
# 50%      2.840000e+00
# 75%      5.570000e+00
# max      7.389500e+02
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    1.161394e+07
# mean     4.481643e+00
# std      4.984150e+00
# min      0.000000e+00
# 25%      1.550000e+00
# 50%      2.820000e+00
# 75%      5.530000e+00
# max      5.271100e+02
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    1.422739e+07
# mean     4.643827e+00
# std      5.152294e+00
# min      0.000000e+00
# 25%      1.600000e+00
# 50%      2.938000e+00
# 75%      5.740000e+00
# max      4.017600e+02
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    1.411137e+07
# mean     4.692196e+00
# std      5.248558e+00
# min      0.000000e+00
# 25%      1.620000e+00
# 50%      2.950000e+00
# 75%      5.774000e+00
# max      4.251000e+02
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    1.471917e+07
# mean     4.843593e+00
# std      5.493553e+00
# min      0.000000e+00
# 25%      1.650000e+00
# 50%      3.014000e+00
# 75%      5.956000e+00
# max      4.121300e+02
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    1.496189e+07
# mean     4.902016e+00
# std      5.646517e+00
# min      0.000000e+00
# 25%      1.655000e+00
# 50%      3.030000e+00
# 75%      6.000000e+00
# max      3.703400e+02
# Name: trip_miles, dtype: float64

# %% [markdown]
# Las distancias de 0 millas parecen ser errores. Veamos algunos ejemplos.

# %%
tlc_21_01[tlc_21_01.trip_miles == 0].head()
# Out:
#      hvfhs_license_num dispatching_base_num originating_base_num  \
# 745             HV0005               B02510                 None
# 961             HV0003               B02870               B02870
# 5737            HV0003               B02836               B02836
# 6925            HV0004               B02800                 None
# 7516            HV0003               B02866               B02866
#
#         request_datetime   on_scene_datetime     pickup_datetime  \
# 745  2021-01-01 00:27:39                 NaT 2021-01-01 00:37:32
# 961  2021-01-01 00:19:00 2021-01-01 00:22:13 2021-01-01 00:23:59
# 5737 2021-01-01 00:30:14 2021-01-01 00:33:16 2021-01-01 00:35:17
# 6925 2021-01-01 00:38:25                 NaT 2021-01-01 00:49:43
# 7516 2021-01-01 00:32:26 2021-01-01 00:36:41 2021-01-01 00:37:57
#
#         dropoff_datetime  PULocationID  DOLocationID  trip_miles  trip_time  \
# 745  2021-01-01 00:39:18           248           248         0.0        106
# 961  2021-01-01 00:24:09            19            19         0.0         10
# 5737 2021-01-01 00:35:33           258           258         0.0         16
# 6925 2021-01-01 00:49:51           141           238         0.0          7
# 7516 2021-01-01 00:41:06           218           218         0.0        189
#
#       base_passenger_fare  tolls   bcf  sales_tax  congestion_surcharge  \
# 745                 12.42   0.71  0.39       1.17                  0.00
# 961                 -0.86   0.00  0.22       0.64                  0.00
# 5737                 7.29   0.00  0.22       0.65                  0.00
# 6925                16.95   0.00  0.00       1.20                  2.75
# 7516                 7.19   0.00  0.22       0.64                  0.00
#
#       airport_fee  tips  driver_pay shared_request_flag shared_match_flag  \
# 745           NaN   0.0        5.47                   N                 N
# 961           NaN   0.0        0.74                   N                 N
# 5737          NaN   0.0        6.93                   N                 N
# 6925          NaN   0.0        0.00                   N                 N
# 7516          NaN   0.0        7.25                   N                 N
#
#      access_a_ride_flag wav_request_flag wav_match_flag
# 745                   N                N              N
# 961                                    N              N
# 5737                                   N              N
# 6925                  N                N              N
# 7516                                   N              N

# %% [markdown]
# Vemos que en general son viajes cortos, dentro del mismo burough. Pueden ser errores o pueden ser viajes menores a 0,1 millas (160 m). Vamos a analizar outliers.

# %%
sns.boxplot(data = tlc_21_01, y="trip_miles");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Se observan numerosos outliers por este método. Quedará determinar si corresponde a errores o es debido a la dispersión de los datos. La superficie de NYC es de aproximadamente 468 millas cuadradas.

# %% [markdown]
# ## trip_time

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.trip_time.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"La descripción de cada mes es: "
          f"{df.trip_time.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.190847e+07
# mean     9.542893e+02
# std      6.240636e+02
# min      0.000000e+00
# 25%      5.240000e+02
# 50%      8.040000e+02
# 75%      1.216000e+03
# max      5.914300e+04
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    1.161394e+07
# mean     1.010675e+03
# std      6.719515e+02
# min      0.000000e+00
# 25%      5.480000e+02
# 50%      8.460000e+02
# 75%      1.288000e+03
# max      7.554000e+04
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    1.422739e+07
# mean     1.033777e+03
# std      7.003532e+02
# min      0.000000e+00
# 25%      5.530000e+02
# 50%      8.600000e+02
# 75%      1.319000e+03
# max      7.711500e+04
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    1.411137e+07
# mean     1.065728e+03
# std      7.377095e+02
# min      0.000000e+00
# 25%      5.630000e+02
# 50%      8.780000e+02
# 75%      1.356000e+03
# max      8.437800e+04
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    1.471917e+07
# mean     1.093808e+03
# std      7.710549e+02
# min      0.000000e+00
# 25%      5.740000e+02
# 50%      8.960000e+02
# 75%      1.387000e+03
# max      4.905200e+04
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    1.496189e+07
# mean     1.145432e+03
# std      8.339155e+02
# min      0.000000e+00
# 25%      5.910000e+02
# 50%      9.290000e+02
# 75%      1.449000e+03
# max      2.407640e+05
# Name: trip_time, dtype: float64

# %% [markdown]
# Tiempos de viaje de 0 segundos podrían ser errores. Veamos algunos casos.

# %%
tlc_21_01[tlc_21_01.trip_time == 0].head()
# Out:
#         hvfhs_license_num dispatching_base_num originating_base_num  \
# 376082             HV0004               B02800                 None
# 434361             HV0004               B02800                 None
# 579394             HV0004               B02800                 None
# 850561             HV0004               B02800                 None
# 1777354            HV0004               B02800                 None
#
#            request_datetime on_scene_datetime     pickup_datetime  \
# 376082  2021-01-01 21:48:43               NaT 2021-01-01 21:49:22
# 434361  2021-01-02 02:52:22               NaT 2021-01-02 03:07:56
# 579394  2021-01-02 15:47:48               NaT 2021-01-02 15:55:03
# 850561  2021-01-03 12:57:00               NaT 2021-01-03 12:59:27
# 1777354 2021-01-06 09:55:47               NaT 2021-01-06 09:56:39
#
#            dropoff_datetime  PULocationID  DOLocationID  trip_miles  \
# 376082  2021-01-01 21:49:22           170           232         0.0
# 434361  2021-01-02 03:07:57           140           140         0.0
# 579394  2021-01-02 15:55:03           132           107         0.0
# 850561  2021-01-03 12:59:28           263           112         0.0
# 1777354 2021-01-06 09:56:40           162           263         0.0
#
#          trip_time  base_passenger_fare  tolls  bcf  sales_tax  \
# 376082           0                17.26    0.0  0.0       1.23
# 434361           0                 9.42    0.0  0.0       0.67
# 579394           0                56.03    0.0  0.0       3.98
# 850561           0                25.99    0.0  0.0       1.85
# 1777354          0                15.95    0.0  0.0       1.13
#
#          congestion_surcharge  airport_fee  tips  driver_pay  \
# 376082                    0.0          NaN   0.0         0.0
# 434361                    0.0          NaN   0.0         0.0
# 579394                    0.0          NaN   0.0         0.0
# 850561                    0.0          NaN   0.0         0.0
# 1777354                   0.0          NaN   0.0         0.0
#
#         shared_request_flag shared_match_flag access_a_ride_flag  \
# 376082                    N                 N                  N
# 434361                    N                 N                  N
# 579394                    N                 N                  N
# 850561                    N                 N                  N
# 1777354                   N                 N                  N
#
#         wav_request_flag wav_match_flag
# 376082                 N              N
# 434361                 N              N
# 579394                 N              N
# 850561                 N              N
# 1777354                N              N

# %% [markdown]
# Observamos casos donde el pickup_time coincide con el dropoff_time o difieren por pocos segundos, por lo que es factible que se trate de errores. Hagamos un análisis preliminar de outliers.

# %%
sns.boxplot(data = tlc_21_01, y="trip_time");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# También se observan numerosos outliers que corresponderá estudiar.

# %% [markdown]
# ## base_passenger_fare

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.base_passenger_fare.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"La descripción de cada mes es: "
          f"{df.base_passenger_fare.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.190847e+07
# mean     1.719294e+01
# std      1.324411e+01
# min     -2.469000e+02
# 25%      8.700000e+00
# 50%      1.330000e+01
# 75%      2.120000e+01
# max      1.532670e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    1.161394e+07
# mean     1.911772e+01
# std      1.447150e+01
# min     -1.315900e+02
# 25%      9.860000e+00
# 50%      1.503000e+01
# 75%      2.354000e+01
# max      1.374730e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    1.422739e+07
# mean     1.967572e+01
# std      1.484157e+01
# min     -1.579200e+02
# 25%      1.007000e+01
# 50%      1.549000e+01
# 75%      2.435000e+01
# max      1.507900e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    1.411137e+07
# mean     2.131051e+01
# std      1.627672e+01
# min     -1.538400e+02
# 25%      1.090000e+01
# 50%      1.686000e+01
# 75%      2.638000e+01
# max      2.244710e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    1.471917e+07
# mean     2.264384e+01
# std      1.731347e+01
# min     -1.097100e+02
# 25%      1.174000e+01
# 50%      1.807000e+01
# 75%      2.792000e+01
# max      1.493980e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    1.496189e+07
# mean     2.378390e+01
# std      1.857363e+01
# min     -2.948600e+02
# 25%      1.229000e+01
# 50%      1.898000e+01
# 75%      2.931000e+01
# max      1.666520e+03
# Name: base_passenger_fare, dtype: float64

# %% [markdown]
# Las tarifas negativas probablemente sean errores. Aquellas tarifas en el orden de 10^3, también es posible que sean errores, por alejarse del resto de los cuartilos. Hagamos un análisis preliminar de outliers.

# %%
sns.boxplot(data = tlc_21_01, y="base_passenger_fare");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Se observan numerosos outliers por este método, por lo que corresponderá revisar si corresponden a errores en los datos o no.

# %% [markdown]
# ## tolls

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.tolls.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"La descripción de cada mes es: "
          f"{df.tolls.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.190847e+07
# mean     7.090513e-01
# std      2.974593e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.139700e+02
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    1.161394e+07
# mean     7.264736e-01
# std      3.060571e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.295900e+02
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    1.422739e+07
# mean     7.896760e-01
# std      3.150456e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.064200e+02
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    1.411137e+07
# mean     8.256628e-01
# std      3.225815e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.896800e+02
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    1.471917e+07
# mean     8.988637e-01
# std      3.371443e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      9.335000e+01
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    1.496189e+07
# mean     9.377161e-01
# std      3.478592e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.526600e+02
# Name: tolls, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_21_01, y="tolls");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## bcf

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.bcf.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"La descripción de cada mes es: "
          f"{df.bcf.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.190847e+07
# mean     5.285122e-01
# std      4.520942e-01
# min      0.000000e+00
# 25%      2.600000e-01
# 50%      3.900000e-01
# 75%      6.400000e-01
# max      4.785000e+01
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    1.161394e+07
# mean     5.847653e-01
# std      4.845095e-01
# min      0.000000e+00
# 25%      2.900000e-01
# 50%      4.500000e-01
# 75%      7.100000e-01
# max      4.192000e+01
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    1.422739e+07
# mean     6.029509e-01
# std      4.975391e-01
# min      0.000000e+00
# 25%      2.900000e-01
# 50%      4.600000e-01
# 75%      7.400000e-01
# max      4.527000e+01
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    1.411137e+07
# mean     6.566668e-01
# std      5.473369e-01
# min      0.000000e+00
# 25%      3.200000e-01
# 50%      5.000000e-01
# 75%      8.000000e-01
# max      6.815000e+01
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    1.471917e+07
# mean     6.994019e-01
# std      5.828201e-01
# min      0.000000e+00
# 25%      3.500000e-01
# 50%      5.400000e-01
# 75%      8.600000e-01
# max      4.686000e+01
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    1.496189e+07
# mean     7.371501e-01
# std      6.269189e-01
# min      0.000000e+00
# 25%      3.600000e-01
# 50%      5.700000e-01
# 75%      9.000000e-01
# max      8.150000e+01
# Name: bcf, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_21_01, y="bcf");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## sales_tax

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.sales_tax.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"La descripción de cada mes es: "
          f"{df.sales_tax.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.190847e+07
# mean     1.482194e+00
# std      1.132610e+00
# min      0.000000e+00
# 25%      7.500000e-01
# 50%      1.140000e+00
# 75%      1.850000e+00
# max      1.403000e+02
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    1.161394e+07
# mean     1.645351e+00
# std      1.239103e+00
# min      0.000000e+00
# 25%      8.400000e-01
# 50%      1.300000e+00
# 75%      2.060000e+00
# max      1.240100e+02
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    1.422739e+07
# mean     1.689801e+00
# std      1.271763e+00
# min      0.000000e+00
# 25%      8.600000e-01
# 50%      1.330000e+00
# 75%      2.130000e+00
# max      1.085800e+02
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    1.411137e+07
# mean     1.838399e+00
# std      1.403786e+00
# min      0.000000e+00
# 25%      9.300000e-01
# 50%      1.450000e+00
# 75%      2.310000e+00
# max      2.016000e+02
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    1.471917e+07
# mean     1.941560e+00
# std      1.482332e+00
# min      0.000000e+00
# 25%      9.900000e-01
# 50%      1.550000e+00
# 75%      2.450000e+00
# max      1.027100e+02
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    1.496189e+07
# mean     2.028488e+00
# std      1.588135e+00
# min      0.000000e+00
# 25%      1.030000e+00
# 50%      1.630000e+00
# 75%      2.560000e+00
# max      2.410900e+02
# Name: sales_tax, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_21_01, y="sales_tax");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## congestion_surcharge

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.congestion_surcharge.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"La descripción de cada mes es: "
          f"{df.congestion_surcharge.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.190847e+07
# mean     8.669806e-01
# std      1.280446e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      5.500000e+00
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    1.161394e+07
# mean     9.041739e-01
# std      1.311921e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      8.250000e+00
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    1.422739e+07
# mean     9.255581e-01
# std      1.308273e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      8.250000e+00
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    1.411137e+07
# mean     9.805839e-01
# std      1.335273e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      5.500000e+00
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    1.471917e+07
# mean     1.029494e+00
# std      1.340632e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      8.250000e+00
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    1.496189e+07
# mean     1.068877e+00
# std      1.360387e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      1.100000e+01
# Name: congestion_surcharge, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_21_01, y="congestion_surcharge");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Se observan outliers por encima del bigote superior. No obstante, dado los valores absolutos, no parecen ser errores.

# %% [markdown]
# ## airport_fee

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.airport_fee.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.9995028747610524
# Promedio de nulos por mes: 0.9999344753056284
# Promedio de nulos por mes: 0.9123672903391367
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %% [markdown]
# Hay un promedio de nulos de 90% en el periodo enero-marzo de 2021, y luego cae a 0 para el periodo abril-junio 2021.

# %%
for df in tlc_21_S1:
    print(f"La descripción de cada mes es: "
          f"{df.airport_fee.describe()}\n")
# Out:
# La descripción de cada mes es: count    5920.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: airport_fee, dtype: float64
#
# La descripción de cada mes es: count    761.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: airport_fee, dtype: float64
#
# La descripción de cada mes es: count    1246785.0
# mean           0.0
# std            0.0
# min            0.0
# 25%            0.0
# 50%            0.0
# 75%            0.0
# max            0.0
# Name: airport_fee, dtype: float64
#
# La descripción de cada mes es: count    1.411137e+07
# mean     7.000802e-02
# std      4.144559e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      6.400000e+00
# Name: airport_fee, dtype: float64
#
# La descripción de cada mes es: count    1.471917e+07
# mean     1.268062e-01
# std      5.510235e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      6.400000e+00
# Name: airport_fee, dtype: float64
#
# La descripción de cada mes es: count    1.496189e+07
# mean     1.347943e-01
# std      5.678414e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      6.400000e+00
# Name: airport_fee, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_21_06, y="airport_fee");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Se observan outliers por encima del bigote superior. No obstante, dado los valores absolutos, no parecen ser errores.

# %% [markdown]
# ## tips

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.tips.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"La descripción de cada mes es: "
          f"{df.tips.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.190847e+07
# mean     4.997583e-01
# std      1.789407e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.000000e+02
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    1.161394e+07
# mean     5.555536e-01
# std      1.957948e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.500000e+02
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    1.422739e+07
# mean     5.718826e-01
# std      2.011425e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      3.000000e+02
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    1.411137e+07
# mean     6.628764e-01
# std      2.245735e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.000000e+02
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    1.471917e+07
# mean     7.623323e-01
# std      2.499099e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+03
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    1.496189e+07
# mean     8.825244e-01
# std      2.770543e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      4.500000e+02
# Name: tips, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_21_01, y="tips");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## driver_pay

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.driver_pay.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"La descripción de cada mes es: "
          f"{df.driver_pay.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.190847e+07
# mean     1.392240e+01
# std      1.108822e+01
# min     -1.165000e+01
# 25%      6.680000e+00
# 50%      1.063000e+01
# 75%      1.728000e+01
# max      1.041770e+03
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    1.161394e+07
# mean     1.576118e+01
# std      1.203643e+01
# min     -4.686000e+01
# 25%      7.760000e+00
# 50%      1.238000e+01
# 75%      1.985000e+01
# max      9.898000e+02
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    1.422739e+07
# mean     1.608288e+01
# std      1.222225e+01
# min     -2.035920e+03
# 25%      8.050000e+00
# 50%      1.270000e+01
# 75%      2.018000e+01
# max      8.725000e+02
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    1.411137e+07
# mean     1.675553e+01
# std      1.285646e+01
# min     -1.608700e+02
# 25%      8.370000e+00
# 50%      1.321000e+01
# 75%      2.101000e+01
# max      1.415730e+03
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    1.471917e+07
# mean     1.820628e+01
# std      1.388465e+01
# min     -8.298000e+01
# 25%      9.220000e+00
# 50%      1.457000e+01
# 75%      2.282000e+01
# max      1.133490e+03
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    1.496189e+07
# mean     1.906058e+01
# std      1.462039e+01
# min     -5.738000e+01
# 25%      9.590000e+00
# 50%      1.542000e+01
# 75%      2.393000e+01
# max      1.053070e+03
# Name: driver_pay, dtype: float64

# %% [markdown]
# Los valores negativos es probable que sean errores. Haremos un análisis preliminar de outliers.

# %%
sns.boxplot(data = tlc_21_01, y="driver_pay");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## shared_request_flag

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.shared_request_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"Los valores únicos por mes: "
          f"{df.shared_request_flag.unique()}")
# Out:
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']

# %% [markdown]
# Las proporciones de pasajeros que solicitaron compartir viajes fueron:

# %%
for df in tlc_21_S1:
    print(df.shared_request_flag.value_counts(normalize=True), "\n")
# Out:
# shared_request_flag
# N    0.999494
# Y    0.000506
# Name: proportion, dtype: float64
#
# shared_request_flag
# N    0.999372
# Y    0.000628
# Name: proportion, dtype: float64
#
# shared_request_flag
# N    0.999218
# Y    0.000782
# Name: proportion, dtype: float64
#
# shared_request_flag
# N    0.999143
# Y    0.000857
# Name: proportion, dtype: float64
#
# shared_request_flag
# N    0.999455
# Y    0.000545
# Name: proportion, dtype: float64
#
# shared_request_flag
# N    0.999554
# Y    0.000446
# Name: proportion, dtype: float64

# %% [markdown]
# ## shared_match_flag

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.shared_match_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"Los valores únicos por mes: "
          f"{df.shared_match_flag.unique()}")
# Out:
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']

# %%
for df in tlc_21_S1:
    print(df.shared_match_flag.value_counts(normalize=True), "\n")
# Out:
# shared_match_flag
# N    0.999899
# Y    0.000101
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    0.999884
# Y    0.000116
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    0.999635
# Y    0.000365
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    0.999498
# Y    0.000502
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    0.999686
# Y    0.000314
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    0.99975
# Y    0.00025
# Name: proportion, dtype: float64

# %% [markdown]
# En todos los meses, menos del 1% de los pasajeros compartieron viajes.

# %% [markdown]
# ## access_a_ride_flag

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.access_a_ride_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"Los valores únicos por mes: "
          f"{df.access_a_ride_flag.unique()}")
# Out:
# Los valores únicos por mes: [' ' 'N']
# Los valores únicos por mes: [' ' 'N']
# Los valores únicos por mes: [' ' 'N']
# Los valores únicos por mes: [' ' 'N']
# Los valores únicos por mes: [' ' 'N']
# Los valores únicos por mes: [' ' 'N']

# %% [markdown]
# Según el diccionario de datos, esta columna puede tomar los valores 'Y' o 'N'. La presencia de un string vacio puede hablar de problemas en la calidad de los datos.

# %% [markdown]
# ## wav_request_flag

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.wav_request_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"Los valores únicos por mes: "
          f"{df.wav_request_flag.unique()}")
# Out:
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']

# %%
for df in tlc_21_S1:
    print(df.wav_request_flag.value_counts(normalize=True), "\n")
# Out:
# wav_request_flag
# N    0.998528
# Y    0.001472
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.998531
# Y    0.001469
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.997974
# Y    0.002026
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.998297
# Y    0.001703
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.998493
# Y    0.001507
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.998458
# Y    0.001542
# Name: proportion, dtype: float64

# %% [markdown]
# En todos los meses, menos del 1% de los pasajeros solicitaron vehículos accesibles para sillas de ruedas.

# %% [markdown]
# ## wav_match_flag

# %%
for df in tlc_21_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.wav_match_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_21_S1:
    print(f"Los valores únicos por mes: "
          f"{df.wav_match_flag.unique()}")
# Out:
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']

# %%
for df in tlc_21_S1:
    print(df.wav_match_flag.value_counts(normalize=True), "\n")
# Out:
# wav_match_flag
# N    0.951604
# Y    0.048396
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.951279
# Y    0.048721
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.950079
# Y    0.049921
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.948782
# Y    0.051218
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.948374
# Y    0.051626
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.946964
# Y    0.053036
# Name: proportion, dtype: float64

# %% [markdown]
# En todos los meses, entre el 4 y el 5% de los viajes sucedieron en vehículos accesibles para sillas de ruedas.
