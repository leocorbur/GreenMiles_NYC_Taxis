# %% [markdown]
# En este archivo haremos un análisis exploratorio preliminar de los viajes de los "High Volume For-Hire Vehicle (HVFHV)" para el __primer semestre__ del año __2020__. Esta categoría empezó a aplicarse en Febrero de 2019 en NYC a vehículos con más de 10000 viajes por día.

# %%
import modin.pandas as pd
from distributed import Client
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# Inicializa un cliente Dask para la ejecución distribuida en múltiples núcleos
client = Client(memory_limit='8GB')

# %%
tlc_20_01 = pd.read_parquet("../raw_data/fhvhv_tripdata_2020-01.parquet")
tlc_20_02 = pd.read_parquet("../raw_data/fhvhv_tripdata_2020-02.parquet")
tlc_20_03 = pd.read_parquet("../raw_data/fhvhv_tripdata_2020-03.parquet")
tlc_20_04 = pd.read_parquet("../raw_data/fhvhv_tripdata_2020-04.parquet")
tlc_20_05 = pd.read_parquet("../raw_data/fhvhv_tripdata_2020-05.parquet")
tlc_20_06 = pd.read_parquet("../raw_data/fhvhv_tripdata_2020-06.parquet")

# %%
# Todos los dataframes del primer semestre de 2020.
tlc_20_S1 = [tlc_20_01, tlc_20_02, tlc_20_03, tlc_20_04, tlc_20_05, tlc_20_06]

# %% [markdown]
# ## Estructura general

# %%
tlc_20_01.dtypes
# Out:
# hvfhs_license_num               object
# dispatching_base_num            object
# originating_base_num            object
# request_datetime        datetime64[ns]
# on_scene_datetime       datetime64[ns]
# pickup_datetime         datetime64[ns]
# dropoff_datetime        datetime64[ns]
# PULocationID                     int64
# DOLocationID                     int64
# trip_miles                     float64
# trip_time                        int64
# base_passenger_fare            float64
# tolls                          float64
# bcf                            float64
# sales_tax                      float64
# congestion_surcharge           float64
# airport_fee                    float64
# tips                           float64
# driver_pay                     float64
# shared_request_flag             object
# shared_match_flag               object
# access_a_ride_flag              object
# wav_request_flag                object
# wav_match_flag                  object
# dtype: object

# %% [markdown]
# Hay 24 columnas:
# * 4 de tipo datetime.
# * 9 de tipo float.
# * 3 de tipo int.
# * 8 de tipo object.

# %%
for df in tlc_20_S1:
    print(f"Filas: {df.shape[0]}")
# Out:
# Filas: 20569368
# Filas: 21725100
# Filas: 13392928
# Filas: 4312909
# Filas: 6089999
# Filas: 7555193

# %%
tlc_20_01.head()
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B02864               B02864
# 1            HV0003               B02682               B02682
# 2            HV0003               B02764               B02764
# 3            HV0003               B02764               B02764
# 4            HV0003               B02764               B02764
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2020-01-01 00:40:13 2020-01-01 00:43:34 2020-01-01 00:45:34
# 1 2020-01-01 00:42:31 2020-01-01 00:46:33 2020-01-01 00:47:50
# 2 2020-01-01 00:01:42 2020-01-01 00:02:06 2020-01-01 00:04:37
# 3 2020-01-01 00:21:23 2020-01-01 00:26:02 2020-01-01 00:26:36
# 4 2020-01-01 00:32:20 2020-01-01 00:37:06 2020-01-01 00:37:49
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  trip_time  \
# 0 2020-01-01 01:02:20           148            90        1.93       1006
# 1 2020-01-01 00:53:23           114            79        0.81        333
# 2 2020-01-01 00:21:49             4           125        2.53       1032
# 3 2020-01-01 00:33:00           231           113        1.11        384
# 4 2020-01-01 00:46:59           114           144        1.10        550
#
#    base_passenger_fare  tolls   bcf  sales_tax  congestion_surcharge  \
# 0                30.44    0.0  0.76       2.70                  2.75
# 1                14.80    0.0  0.37       1.31                  2.75
# 2                15.63    0.0  0.47       1.39                  2.75
# 3                 8.44    0.0  0.21       0.75                  2.75
# 4                11.57    0.0  0.29       1.03                  2.75
#
#    airport_fee  tips  driver_pay shared_request_flag shared_match_flag  \
# 0          NaN   0.0       18.25                   N                 N
# 1          NaN   0.0       10.84                   N                 N
# 2          NaN   3.0       11.73                   N                 N
# 3          NaN   0.0        5.84                   N                 N
# 4          NaN   0.0        7.69                   N                 N
#
#   access_a_ride_flag wav_request_flag wav_match_flag
# 0                                   N              N
# 1                                   N              N
# 2                                   N              N
# 3                                   N              N
# 4                                   N              N

# %% [markdown]
# ## Duplicados

# %% [markdown]
# Vamos a analizar la presencia de duplicados. Al haber tantas columnas, vamos a elegir un subset representativo. En caso de encontrar duplicados aplicaremos distintas estrategias.

# %%
#tlc_20_01.duplicated().sum()
# Out:
# 216

# %%
#tlc_20_02.duplicated().sum()
# Out:
# 0

# %%
#tlc_20_03.duplicated().sum()
# Out:
# 0

# %%
#tlc_20_04.duplicated().sum()
# Out:
# 0

# %%
#tlc_20_05.duplicated().sum()
# Out:
# 0

# %%
#tlc_20_06.duplicated().sum()
# Out:
# 419

# %% [markdown]
# ## hvfhs_license_num

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.hvfhs_license_num.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"Los valores únicos por mes: "
          f"{df.hvfhs_license_num.unique()}")
# Out:
# Los valores únicos por mes: ['HV0003' 'HV0005' 'HV0004']
# Los valores únicos por mes: ['HV0003' 'HV0005' 'HV0004']
# Los valores únicos por mes: ['HV0005' 'HV0003' 'HV0004']
# Los valores únicos por mes: ['HV0003' 'HV0005' 'HV0004']
# Los valores únicos por mes: ['HV0003' 'HV0004' 'HV0005']
# Los valores únicos por mes: ['HV0005' 'HV0003' 'HV0004']

# %%
for df in tlc_20_S1:
    print(df.hvfhs_license_num.value_counts(normalize=True), "\n")
# Out:
# UserWarning: `df.groupby(categorical_by, sort=False)` implementation has mismatches with pandas:
# the groupby keys will be sorted anyway, although the 'sort=False' was passed. See the following issue for more details: https://github.com/modin-project/modin/issues/3571.
# hvfhs_license_num
# HV0003    0.708944
# HV0005    0.256413
# HV0004    0.034644
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.724674
# HV0005    0.245778
# HV0004    0.029548
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.734476
# HV0005    0.240391
# HV0004    0.025133
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.719430
# HV0005    0.265269
# HV0004    0.015301
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.715826
# HV0005    0.266255
# HV0004    0.017919
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.676926
# HV0005    0.305864
# HV0004    0.017210
# Name: proportion, dtype: float64

# %% [markdown]
# Entre el 71-73% de las licencias corresponden a HV0003 (Uber) entre el 24-30% de las licencias corresponden a HV0005 (Lyft) y menos del 1% corresponden a HV0004 (Via).

# %% [markdown]
# ## dispatching_base_num

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.dispatching_base_num.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"Los valores únicos por mes: "
          f"{sorted(df.dispatching_base_num.unique())}")
# Out:
# Los valores únicos por mes: ['B02395', 'B02510', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02800', 'B02835', 'B02836', 'B02844', 'B02864', 'B02865', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02878', 'B02879', 'B02880', 'B02882', 'B02883', 'B02884', 'B02887', 'B02888', 'B02889', 'B03136']
# Los valores únicos por mes: ['B02395', 'B02510', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02800', 'B02835', 'B02836', 'B02844', 'B02864', 'B02865', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02878', 'B02879', 'B02880', 'B02882', 'B02883', 'B02884', 'B02887', 'B02888', 'B02889', 'B03136']
# Los valores únicos por mes: ['B02395', 'B02510', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02800', 'B02835', 'B02836', 'B02844', 'B02864', 'B02865', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02878', 'B02879', 'B02880', 'B02882', 'B02883', 'B02884', 'B02887', 'B02888', 'B02889', 'B03136']
# Los valores únicos por mes: ['B02395', 'B02510', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02800', 'B02835', 'B02836', 'B02844', 'B02864', 'B02865', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02878', 'B02879', 'B02880', 'B02882', 'B02883', 'B02884', 'B02887', 'B02888', 'B02889', 'B03136']
# Los valores únicos por mes: ['B02395', 'B02510', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02800', 'B02835', 'B02836', 'B02844', 'B02864', 'B02865', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02878', 'B02879', 'B02880', 'B02882', 'B02883', 'B02884', 'B02887', 'B02888', 'B02889', 'B03136']
# Los valores únicos por mes: ['B02395', 'B02510', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02800', 'B02835', 'B02836', 'B02844', 'B02864', 'B02865', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02878', 'B02879', 'B02880', 'B02882', 'B02883', 'B02884', 'B02887', 'B02888', 'B02889', 'B03136']

# %% [markdown]
# Cada base está asociada con una compañía distinta.

# %% [markdown]
# ## originating_base_num

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.originating_base_num.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.2908277493017773
# Promedio de nulos por mes: 0.27511509728378697
# Promedio de nulos por mes: 0.2652517059749743
# Promedio de nulos por mes: 0.2801821230172025
# Promedio de nulos por mes: 0.2837240203159311
# Promedio de nulos por mes: 0.32297838056552625

# %% [markdown]
# Hay un promedio de 26-32% de valores faltantes en esta columna.

# %%
for df in tlc_20_S1:
    print(f"Los valores únicos por mes: "
          f"{df.originating_base_num.unique()}")
# Out:
# Los valores únicos por mes: ['B02864' 'B02682' 'B02764' 'B02870' 'B02836' 'B02875' 'B02617' 'B02883'
#  'B02872' None 'B02882' 'B02869' 'B02887' 'B02765' 'B02879' 'B02880'
#  'B02888' 'B02871' 'B02835' 'B02884' 'B02877' 'B02878' 'B02876' 'B02889'
#  'B02395' 'B02867' 'B02866' 'B02865' 'B02512' 'B02844' 'B02800' 'B03136'
#  'B02729' 'B03153' 'B00446' 'B02390' 'B02537' 'B02510' 'B02913' 'B00887']
# Los valores únicos por mes: ['B02872' 'B02682' 'B02764' None 'B02875' 'B02836' 'B02869' 'B02887'
#  'B02888' 'B02879' 'B02882' 'B02880' 'B02617' 'B02883' 'B02866' 'B02876'
#  'B02878' 'B02864' 'B02765' 'B02884' 'B02871' 'B02889' 'B02512' 'B02395'
#  'B02865' 'B02835' 'B02877' 'B02870' 'B02867' 'B02510' 'B03136' 'B02800'
#  'B02729' 'B03153' 'B02826' 'B01985' 'B00887' 'B02913' 'B00457' 'B00446'
#  'B02468']
# Los valores únicos por mes: [None 'B02764' 'B02682' 'B02765' 'B02864' 'B02880' 'B02882' 'B02869'
#  'B02884' 'B02887' 'B02836' 'B02879' 'B02872' 'B02617' 'B02866' 'B02876'
#  'B02888' 'B02878' 'B02883' 'B02835' 'B02875' 'B02889' 'B02871' 'B02395'
#  'B02867' 'B02877' 'B02865' 'B02512' 'B02870' 'B03136' 'B02510' 'B02800'
#  'B02729' 'B02826' 'B01312' 'B00887' 'B03153' 'B01985' 'B02468']
# Los valores únicos por mes: ['B02875' None 'B02836' 'B02764' 'B02872' 'B02871' 'B02879' 'B02882'
#  'B02617' 'B02880' 'B02682' 'B02889' 'B02869' 'B02887' 'B02864' 'B02877'
#  'B02835' 'B02883' 'B02878' 'B02876' 'B02765' 'B02395' 'B02867' 'B02884'
#  'B02866' 'B02870' 'B02888' 'B02865' 'B02512' 'B02510' 'B02800' 'B03136'
#  'B02729' 'B02826' 'B00446' 'B03153' 'B00887']
# Los valores únicos por mes: ['B02764' 'B02875' None 'B02872' 'B02883' 'B02765' 'B02836' 'B02869'
#  'B02867' 'B02617' 'B02879' 'B02882' 'B02878' 'B02871' 'B02682' 'B02877'
#  'B02512' 'B02884' 'B02395' 'B02864' 'B02866' 'B02887' 'B02870' 'B02876'
#  'B02835' 'B02888' 'B02889' 'B02880' 'B02865' 'B02800' 'B02510' 'B02729'
#  'B03136' 'B00446' 'B02826' 'B00887' 'B03153']
# Los valores únicos por mes: [None 'B02764' 'B02888' 'B02617' 'B02883' 'B02875' 'B02879' 'B02836'
#  'B02867' 'B02882' 'B02866' 'B02889' 'B02869' 'B02765' 'B02884' 'B02877'
#  'B02876' 'B02682' 'B02880' 'B02871' 'B02872' 'B02512' 'B02878' 'B02887'
#  'B02395' 'B02835' 'B02864' 'B02870' 'B02865' 'B02510' 'B02800' 'B03136'
#  'B02729' 'B02826' 'B00887' 'B03153' 'B00446' 'B00457']

# %% [markdown]
# ## request_datetime

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.request_datetime.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 1.6420363944230533e-07
# Promedio de nulos por mes: 0.0

# %% [markdown]
# El promedio de nulos es muy bajo.

# %%
for df in tlc_20_S1:
    print(f"La descripción de cada mes es: "
          f"{df.request_datetime.describe()}\n")
# Out:
# La descripción de cada mes es: count                         20569368
# mean     2020-01-17 01:15:47.482221056
# min                2019-12-31 22:59:17
# 25%                2020-01-09 17:07:10
# 50%                2020-01-17 11:37:08
# 75%                2020-01-24 19:35:46
# max                2020-01-31 23:59:28
# Name: request_datetime, dtype: object
#
# La descripción de cada mes es: count                         21725100
# mean     2020-02-15 18:24:39.466567680
# min                2020-01-31 22:44:20
# 25%                2020-02-08 11:48:13
# 50%         2020-02-15 14:50:50.500000
# 75%                2020-02-22 23:29:49
# max                2020-03-01 00:10:00
# Name: request_datetime, dtype: object
#
# La descripción de cada mes es: count                         13392928
# mean     2020-03-11 11:51:10.619442944
# min                2020-02-29 16:22:20
# 25%                2020-03-05 18:50:37
# 50%         2020-03-10 00:19:26.500000
# 75%                2020-03-15 14:07:42
# max                2020-04-01 00:10:00
# Name: request_datetime, dtype: object
#
# La descripción de cada mes es: count                          4312909
# mean     2020-04-16 19:16:02.305196288
# min                2020-03-31 23:35:40
# 25%                2020-04-09 12:16:32
# 50%                2020-04-17 08:07:09
# 75%                2020-04-24 09:17:21
# max                2020-05-01 00:10:00
# Name: request_datetime, dtype: object
#
# La descripción de cada mes es: count                          6089998
# mean     2020-05-17 07:47:05.142799616
# min                2020-04-30 22:47:58
# 25%                2020-05-09 14:08:02
# 50%                2020-05-17 14:32:12
# 75%         2020-05-25 07:05:06.500000
# max                2020-06-01 00:10:00
# Name: request_datetime, dtype: object
#
# La descripción de cada mes es: count                          7555193
# mean     2020-06-17 04:05:19.527871744
# min                2020-05-31 23:16:43
# 25%                2020-06-10 06:55:57
# 50%                2020-06-17 16:43:38
# 75%                2020-06-24 15:58:25
# max                2020-07-01 00:10:00
# Name: request_datetime, dtype: object

# %% [markdown]
# No se observan outliers. Los valores extremos se superponen entre meses en algunos casos.

# %% [markdown]
# ## on_scene_datetime

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.on_scene_datetime.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.2908277493017773
# Promedio de nulos por mes: 0.27511509728378697
# Promedio de nulos por mes: 0.2652518553075175
# Promedio de nulos por mes: 0.2801821230172025
# Promedio de nulos por mes: 0.28372418451957054
# Promedio de nulos por mes: 0.3225200203356817

# %% [markdown]
# Hay un promedio de 26-32% de valores faltantes en esta columna.

# %%
for df in tlc_20_S1:
    print(f"La descripción de cada mes es: "
          f"{df.on_scene_datetime.describe()}\n")
# Out:
# La descripción de cada mes es: count                         14587225
# mean     2020-01-17 00:16:01.454097920
# min                2019-12-31 23:46:18
# 25%                2020-01-09 15:16:21
# 50%                2020-01-17 09:38:43
# 75%                2020-01-24 19:36:37
# max                2020-02-01 00:02:16
# Name: on_scene_datetime, dtype: object
#
# La descripción de cada mes es: count                         15748197
# mean     2020-02-15 20:23:21.799357952
# min                2020-01-31 22:48:25
# 25%                2020-02-08 12:39:16
# 50%                2020-02-15 17:00:00
# 75%                2020-02-23 01:24:57
# max                2020-02-29 23:59:57
# Name: on_scene_datetime, dtype: object
#
# La descripción de cada mes es: count                          9840429
# mean     2020-03-11 13:54:56.767942144
# min                2020-02-29 16:24:35
# 25%                2020-03-05 19:22:35
# 50%                2020-03-10 06:38:02
# 75%                2020-03-15 17:52:24
# max                2020-03-31 23:59:19
# Name: on_scene_datetime, dtype: object
#
# La descripción de cada mes es: count                          3104509
# mean     2020-04-16 19:27:08.222248192
# min                2020-03-31 23:56:32
# 25%                2020-04-09 12:20:30
# 50%                2020-04-17 07:51:01
# 75%                2020-04-24 09:22:32
# max                2020-04-30 23:59:19
# Name: on_scene_datetime, dtype: object
#
# La descripción de cada mes es: count                          4362119
# mean     2020-05-17 05:01:19.106944512
# min                2020-04-30 22:55:22
# 25%                2020-05-09 11:13:54
# 50%                2020-05-17 10:17:59
# 75%         2020-05-25 00:31:59.500000
# max                2020-05-31 23:59:48
# Name: on_scene_datetime, dtype: object
#
# La descripción de cada mes es: count                          5118492
# mean     2020-06-17 04:03:35.037054464
# min                2020-05-31 23:55:44
# 25%      2020-06-10 00:54:56.750000128
# 50%         2020-06-17 17:34:11.500000
# 75%                2020-06-24 16:59:16
# max                2020-06-30 23:59:26
# Name: on_scene_datetime, dtype: object

# %% [markdown]
# No se observan outliers. Los valores extremos se superponen entre meses en algunos casos.

# %% [markdown]
# ## pickup_datetime

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.pickup_datetime.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"La descripción de cada mes es: "
          f"{df.pickup_datetime.describe()}\n")
# Out:
# La descripción de cada mes es: count                         20569368
# mean     2020-01-17 01:20:09.866663680
# min                2020-01-01 00:00:00
# 25%                2020-01-09 17:11:32
# 50%                2020-01-17 11:41:21
# 75%                2020-01-24 19:40:04
# max                2020-01-31 23:59:59
# Name: pickup_datetime, dtype: object
#
# La descripción de cada mes es: count                         21725100
# mean     2020-02-15 18:29:18.510545664
# min                2020-02-01 00:00:00
# 25%                2020-02-08 11:52:42
# 50%                2020-02-15 14:55:11
# 75%                2020-02-22 23:34:45
# max                2020-02-29 23:59:59
# Name: pickup_datetime, dtype: object
#
# La descripción de cada mes es: count                         13392928
# mean     2020-03-11 11:55:43.349130240
# min                2020-03-01 00:00:00
# 25%                2020-03-05 18:55:48
# 50%                2020-03-10 00:23:46
# 75%                2020-03-15 14:11:30
# max                2020-03-31 23:59:59
# Name: pickup_datetime, dtype: object
#
# La descripción de cada mes es: count                          4312909
# mean     2020-04-16 19:20:57.792399360
# min                2020-04-01 00:00:00
# 25%                2020-04-09 12:20:32
# 50%                2020-04-17 08:11:52
# 75%                2020-04-24 09:21:13
# max                2020-04-30 23:59:59
# Name: pickup_datetime, dtype: object
#
# La descripción de cada mes es: count                          6089999
# mean     2020-05-17 07:51:44.016944640
# min                2020-05-01 00:00:00
# 25%         2020-05-09 14:11:50.500000
# 50%                2020-05-17 14:36:36
# 75%                2020-05-25 07:09:40
# max                2020-05-31 23:59:59
# Name: pickup_datetime, dtype: object
#
# La descripción de cada mes es: count                          7555193
# mean     2020-06-17 04:11:18.254674944
# min                2020-06-01 00:00:00
# 25%                2020-06-10 07:00:57
# 50%                2020-06-17 16:49:50
# 75%                2020-06-24 16:04:06
# max                2020-06-30 23:59:58
# Name: pickup_datetime, dtype: object

# %% [markdown]
# No se observan outliers ni superposiciones entre los meses.

# %% [markdown]
# ## dropoff_datetime

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.dropoff_datetime.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"La descripción de cada mes es: "
          f"{df.dropoff_datetime.describe()}\n")
# Out:
# La descripción de cada mes es: count                         20569368
# mean     2020-01-17 01:37:30.302956800
# min                2020-01-01 00:01:17
# 25%                2020-01-09 17:31:10
# 50%                2020-01-17 11:59:11
# 75%                2020-01-24 19:57:17
# max                2020-02-01 04:05:40
# Name: dropoff_datetime, dtype: object
#
# La descripción de cada mes es: count                         21725100
# mean     2020-02-15 18:47:01.886547456
# min                2020-02-01 00:02:11
# 25%                2020-02-08 12:08:46
# 50%                2020-02-15 15:12:01
# 75%                2020-02-22 23:51:36
# max                2020-03-01 07:03:21
# Name: dropoff_datetime, dtype: object
#
# La descripción de cada mes es: count                         13392928
# mean     2020-03-11 12:12:38.851674368
# min                2020-03-01 00:02:03
# 25%                2020-03-05 19:15:09
# 50%                2020-03-10 00:39:24
# 75%                2020-03-15 14:27:00
# max                2020-04-01 01:17:28
# Name: dropoff_datetime, dtype: object
#
# La descripción de cada mes es: count                          4312909
# mean     2020-04-16 19:34:39.157822720
# min                2020-04-01 00:04:08
# 25%                2020-04-09 12:33:40
# 50%                2020-04-17 08:26:16
# 75%                2020-04-24 09:35:16
# max                2020-05-01 01:12:16
# Name: dropoff_datetime, dtype: object
#
# La descripción de cada mes es: count                          6089999
# mean     2020-05-17 08:06:45.809860096
# min                2020-05-01 00:00:53
# 25%                2020-05-09 14:26:25
# 50%                2020-05-17 14:51:39
# 75%                2020-05-25 07:23:58
# max                2020-06-01 09:39:18
# Name: dropoff_datetime, dtype: object
#
# La descripción de cada mes es: count                          7555193
# mean     2020-06-17 04:27:47.783416576
# min                2020-06-01 00:03:07
# 25%                2020-06-10 07:16:14
# 50%                2020-06-17 17:09:15
# 75%                2020-06-24 16:23:35
# max                2020-07-01 07:15:22
# Name: dropoff_datetime, dtype: object

# %% [markdown]
# No se observan outliers. Los valores extremos se superponen entre meses en algunos casos.

# %% [markdown]
# ## PULocationID

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.PULocationID.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"El número de zonas únicas de cada mes es: "
          f"{df.PULocationID.nunique()}")
# Out:
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 261
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 260
# El número de zonas únicas de cada mes es: 260
# El número de zonas únicas de cada mes es: 260

# %% [markdown]
# Es la zona de taxi TLC donde inició el viaje. Hay 265 en total.

# %%
for df in tlc_20_S1:
    print(f"Mínimo: {df.PULocationID.min()}, Máximo {df.PULocationID.max()}")
# Out:
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265

# %% [markdown]
# No se observan outliers en esta columna.

# %% [markdown]
# ## DOLocationID

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.DOLocationID.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"El número de zonas únicas de cada mes es: "
          f"{df.DOLocationID.nunique()}")
# Out:
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 261
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 261

# %% [markdown]
# Es la zona de taxi TLC donde culminó el viaje. Hay 265 en total.

# %%
for df in tlc_20_S1:
    print(f"Mínimo: {df.DOLocationID.min()}, Máximo {df.DOLocationID.max()}")
# Out:
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265

# %% [markdown]
# No se observan outliers en esta columna.

# %% [markdown]
# ## trip_miles

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.trip_miles.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"La descripción de cada mes es: "
          f"{df.trip_miles.describe()}\n")
# Out:
# La descripción de cada mes es: count    2.056937e+07
# mean     4.556780e+00
# std      5.415823e+00
# min      0.000000e+00
# 25%      1.483000e+00
# 50%      2.710000e+00
# 75%      5.478000e+00
# max      3.395500e+02
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    2.172510e+07
# mean     4.548314e+00
# std      5.273029e+00
# min      0.000000e+00
# 25%      1.503000e+00
# 50%      2.750000e+00
# 75%      5.500000e+00
# max      4.682800e+02
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    1.339293e+07
# mean     4.604680e+00
# std      5.290254e+00
# min      0.000000e+00
# 25%      1.570000e+00
# 50%      2.862000e+00
# 75%      5.630000e+00
# max      1.310510e+03
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    4.312909e+06
# mean     4.608681e+00
# std      4.935660e+00
# min      0.000000e+00
# 25%      1.670000e+00
# 50%      3.040000e+00
# 75%      5.820000e+00
# max      5.650600e+02
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    6.089999e+06
# mean     4.716445e+00
# std      5.056233e+00
# min      0.000000e+00
# 25%      1.730000e+00
# 50%      3.120000e+00
# 75%      5.890000e+00
# max      5.976600e+02
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    7.555193e+06
# mean     4.837734e+00
# std      5.201041e+00
# min      0.000000e+00
# 25%      1.750000e+00
# 50%      3.170000e+00
# 75%      6.040000e+00
# max      3.514900e+02
# Name: trip_miles, dtype: float64

# %% [markdown]
# Las distancias de 0 millas parecen ser errores. Veamos algunos ejemplos.

# %%
tlc_20_01[tlc_20_01.trip_miles == 0].head()
# Out:
#     hvfhs_license_num dispatching_base_num originating_base_num  \
# 34             HV0005               B02510                 None
# 35             HV0005               B02510                 None
# 117            HV0005               B02510                 None
# 127            HV0005               B02510                 None
# 128            HV0005               B02510                 None
#
#        request_datetime on_scene_datetime     pickup_datetime  \
# 34  2020-01-01 00:26:08               NaT 2020-01-01 00:43:30
# 35  2020-01-01 00:37:21               NaT 2020-01-01 00:53:32
# 117 2020-01-01 00:16:30               NaT 2020-01-01 00:20:12
# 127 2020-01-01 00:37:39               NaT 2020-01-01 00:44:46
# 128 2020-01-01 00:41:12               NaT 2020-01-01 00:47:05
#
#        dropoff_datetime  PULocationID  DOLocationID  trip_miles  trip_time  \
# 34  2020-01-01 01:23:49           148            85         0.0       2419
# 35  2020-01-01 01:09:38           148            17         0.0        966
# 117 2020-01-01 00:34:13            79           233         0.0        841
# 127 2020-01-01 01:08:25           170            66         0.0       1419
# 128 2020-01-01 01:19:21           170            49         0.0       1936
#
#      base_passenger_fare  tolls   bcf  sales_tax  congestion_surcharge  \
# 34                 20.23    0.0  0.51       1.80                  0.75
# 35                 13.20    0.0  0.33       1.17                  0.75
# 117                 6.82    0.0  0.17       0.61                  0.75
# 127                21.88    0.0  0.55       1.94                  0.75
# 128                17.88    0.0  0.50       1.79                  0.75
#
#      airport_fee  tips  driver_pay shared_request_flag shared_match_flag  \
# 34           NaN   0.0         0.0                   Y                 Y
# 35           NaN   0.0         0.0                   Y                 Y
# 117          NaN   0.0         0.0                   Y                 N
# 127          NaN   0.0         0.0                   Y                 Y
# 128          NaN   0.0         0.0                   Y                 Y
#
#     access_a_ride_flag wav_request_flag wav_match_flag
# 34                   N                N              N
# 35                   N                N              N
# 117                  N                N              N
# 127                  N                N              N
# 128                  N                N              N

# %% [markdown]
# Vemos viajes entre buroughs en general. Pueden ser errores o pueden ser viajes menores a 0,1 millas (160 m). Vamos a analizar outliers.

# %%
sns.boxplot(data = tlc_20_01, y="trip_miles");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Se observan numerosos outliers por este método. Quedará determinar si corresponde a errores o es debido a la dispersión de los datos. La superficie de NYC es de aproximadamente 468 millas cuadradas.

# %% [markdown]
# ## trip_time

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.trip_time.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"La descripción de cada mes es: "
          f"{df.trip_time.describe()}\n")
# Out:
# La descripción de cada mes es: count    2.056937e+07
# mean     1.040438e+03
# std      7.094020e+02
# min      0.000000e+00
# 25%      5.470000e+02
# 50%      8.600000e+02
# 75%      1.334000e+03
# max      5.048900e+04
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    2.172510e+07
# mean     1.063388e+03
# std      7.270870e+02
# min      0.000000e+00
# 25%      5.570000e+02
# 50%      8.810000e+02
# 75%      1.368000e+03
# max      8.489400e+04
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    1.339293e+07
# mean     1.013237e+03
# std      6.975439e+02
# min      0.000000e+00
# 25%      5.360000e+02
# 50%      8.370000e+02
# 75%      1.293000e+03
# max      7.209300e+04
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    4.312909e+06
# mean     8.214339e+02
# std      5.218739e+02
# min      0.000000e+00
# 25%      4.740000e+02
# 50%      7.080000e+02
# 75%      1.035000e+03
# max      4.385400e+04
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    6.089999e+06
# mean     9.018230e+02
# std      5.739106e+02
# min      0.000000e+00
# 25%      5.140000e+02
# 50%      7.720000e+02
# 75%      1.139000e+03
# max      8.580400e+04
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    7.555193e+06
# mean     9.895581e+02
# std      6.518564e+02
# min      0.000000e+00
# 25%      5.480000e+02
# 50%      8.330000e+02
# 75%      1.253000e+03
# max      8.579400e+04
# Name: trip_time, dtype: float64

# %% [markdown]
# Tiempos de viaje de 0 segundos podrían ser errores. Veamos algunos casos.

# %%
tlc_20_01[tlc_20_01.trip_time == 0].head()
# Out:
#         hvfhs_license_num dispatching_base_num originating_base_num  \
# 767028             HV0003               B02887               B02887
# 793944             HV0004               B02800                 None
# 2185453            HV0003               B02764               B02764
# 4518758            HV0003               B02875               B02875
# 5314526            HV0003               B02764               B02764
#
#            request_datetime   on_scene_datetime     pickup_datetime  \
# 767028  2020-01-02 06:01:48 2020-01-02 06:01:55 2020-01-02 06:02:11
# 793944  2020-01-02 07:54:27                 NaT 2020-01-02 08:37:13
# 2185453 2020-01-04 17:20:26 2020-01-04 17:24:11 2020-01-04 17:26:11
# 4518758 2020-01-08 17:48:45 2020-01-08 17:53:27 2020-01-08 17:55:22
# 5314526 2020-01-09 21:00:37 2020-01-09 21:00:57 2020-01-09 21:00:57
#
#            dropoff_datetime  PULocationID  DOLocationID  trip_miles  \
# 767028  2020-01-02 06:02:11           144           144         0.0
# 793944  2020-01-02 08:37:13           239           162         0.0
# 2185453 2020-01-04 17:26:12           119           119         0.0
# 4518758 2020-01-08 17:55:22            39            39         0.0
# 5314526 2020-01-09 21:00:57           246           246         0.0
#
#          trip_time  base_passenger_fare  tolls   bcf  sales_tax  \
# 767028           0                 7.19    0.0  0.18       0.64
# 793944           0                 5.25    0.0  0.00       0.37
# 2185453          0               228.21    0.0  0.18       0.64
# 4518758          0                 7.19    0.0  0.18       0.64
# 5314526          0                 7.19    0.0  0.18       0.64
#
#          congestion_surcharge  airport_fee  tips  driver_pay  \
# 767028                   2.75          NaN  0.00        6.09
# 793944                   0.00          NaN  1.05        0.00
# 2185453                  0.00          NaN  0.00      154.18
# 4518758                  0.00          NaN  0.00        0.00
# 5314526                  2.75          NaN  0.00        0.00
#
#         shared_request_flag shared_match_flag access_a_ride_flag  \
# 767028                    N                 N
# 793944                    Y                 N                  N
# 2185453                   N                 N
# 4518758                   N                 N
# 5314526                   N                 N
#
#         wav_request_flag wav_match_flag
# 767028                 N              N
# 793944                 N              N
# 2185453                N              N
# 4518758                N              Y
# 5314526                N              N

# %% [markdown]
# Observamos casos donde el pickup_time coincide con el dropoff_time o difieren por pocos segundos, por lo que es factible que se trate de errores. Hagamos un análisis preliminar de outliers.

# %%
sns.boxplot(data = tlc_20_01, y="trip_time");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# También se observan numerosos outliers que corresponderá estudiar.

# %% [markdown]
# ## base_passenger_fare

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.base_passenger_fare.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"La descripción de cada mes es: "
          f"{df.base_passenger_fare.describe()}\n")
# Out:
# La descripción de cada mes es: count    2.056937e+07
# mean     1.701709e+01
# std      1.611271e+01
# min     -1.277800e+02
# 25%      7.720000e+00
# 50%      1.199000e+01
# 75%      2.029000e+01
# max      1.461660e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    2.172510e+07
# mean     1.656520e+01
# std      1.615643e+01
# min     -2.085200e+02
# 25%      7.190000e+00
# 50%      1.147000e+01
# 75%      2.001000e+01
# max      8.157740e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    1.339293e+07
# mean     1.635973e+01
# std      1.532755e+01
# min     -1.282300e+02
# 25%      7.490000e+00
# 50%      1.179000e+01
# 75%      1.980000e+01
# max      1.336250e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    4.312909e+06
# mean     1.638240e+01
# std      1.263565e+01
# min     -1.135600e+02
# 25%      8.120000e+00
# 50%      1.257000e+01
# 75%      2.005000e+01
# max      1.238760e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    6.089999e+06
# mean     1.755503e+01
# std      1.336668e+01
# min     -1.034800e+02
# 25%      8.850000e+00
# 50%      1.373000e+01
# 75%      2.162000e+01
# max      1.265570e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    7.555193e+06
# mean     1.955532e+01
# std      1.526866e+01
# min     -1.011400e+02
# 25%      9.900000e+00
# 50%      1.521000e+01
# 75%      2.417000e+01
# max      1.130120e+03
# Name: base_passenger_fare, dtype: float64

# %% [markdown]
# Las tarifas negativas probablemente sean errores. Aquellas tarifas en el orden de 10^3, también es posible que sean errores, por alejarse del resto de los cuartilos. Hagamos un análisis preliminar de outliers.

# %%
sns.boxplot(data = tlc_20_01, y="base_passenger_fare");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Se observan numerosos outliers por este método, por lo que corresponderá revisar si corresponden a errores en los datos o no.

# %% [markdown]
# ## tolls

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.tolls.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"La descripción de cada mes es: "
          f"{df.tolls.describe()}\n")
# Out:
# La descripción de cada mes es: count    2.056937e+07
# mean     8.423652e-01
# std      3.417818e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.187200e+02
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    2.172510e+07
# mean     8.511666e-01
# std      3.411343e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.025000e+02
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    1.339293e+07
# mean     7.971854e-01
# std      3.282952e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      9.300000e+01
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    4.312909e+06
# mean     5.711438e-01
# std      2.679145e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      8.928000e+01
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    6.089999e+06
# mean     6.480375e-01
# std      2.878081e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      8.675000e+01
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    7.555193e+06
# mean     7.420924e-01
# std      3.063422e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.003500e+02
# Name: tolls, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_20_01, y="tolls");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## bcf

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.bcf.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"La descripción de cada mes es: "
          f"{df.bcf.describe()}\n")
# Out:
# La descripción de cada mes es: count    2.056937e+07
# mean     4.402388e-01
# std      4.736847e-01
# min      0.000000e+00
# 25%      1.800000e-01
# 50%      2.900000e-01
# 75%      5.200000e-01
# max      3.707000e+01
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    2.172510e+07
# mean     4.248253e-01
# std      4.626944e-01
# min      0.000000e+00
# 25%      1.800000e-01
# 50%      2.800000e-01
# 75%      5.000000e-01
# max      2.039600e+02
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    1.339293e+07
# mean     4.236022e-01
# std      4.464393e-01
# min      0.000000e+00
# 25%      1.800000e-01
# 50%      2.900000e-01
# 75%      5.000000e-01
# max      6.958000e+01
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    4.312909e+06
# mean     4.187853e-01
# std      3.659947e-01
# min      0.000000e+00
# 25%      2.000000e-01
# 50%      3.100000e-01
# 75%      5.100000e-01
# max      3.406000e+01
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    6.089999e+06
# mean     4.489595e-01
# std      3.877056e-01
# min      0.000000e+00
# 25%      2.200000e-01
# 50%      3.400000e-01
# 75%      5.500000e-01
# max      3.216000e+01
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    7.555193e+06
# mean     5.090083e-01
# std      4.512664e-01
# min      0.000000e+00
# 25%      2.400000e-01
# 50%      3.800000e-01
# 75%      6.200000e-01
# max      3.095000e+01
# Name: bcf, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_20_01, y="bcf");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## sales_tax

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.sales_tax.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"La descripción de cada mes es: "
          f"{df.sales_tax.describe()}\n")
# Out:
# La descripción de cada mes es: count    2.056937e+07
# mean     1.405656e+00
# std      1.309837e+00
# min      0.000000e+00
# 25%      6.400000e-01
# 50%      1.000000e+00
# 75%      1.710000e+00
# max      7.202000e+01
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    2.172510e+07
# mean     1.354162e+00
# std      1.295228e+00
# min      0.000000e+00
# 25%      6.400000e-01
# 50%      9.500000e-01
# 75%      1.660000e+00
# max      7.240800e+02
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    1.339293e+07
# mean     1.367589e+00
# std      1.250174e+00
# min      0.000000e+00
# 25%      6.400000e-01
# 50%      9.900000e-01
# 75%      1.690000e+00
# max      9.613000e+01
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    4.312909e+06
# mean     1.424958e+00
# std      1.105838e+00
# min      0.000000e+00
# 25%      7.000000e-01
# 50%      1.090000e+00
# 75%      1.750000e+00
# max      6.297000e+01
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    6.089999e+06
# mean     1.518544e+00
# std      1.154680e+00
# min      0.000000e+00
# 25%      7.600000e-01
# 50%      1.180000e+00
# 75%      1.890000e+00
# max      1.009200e+02
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    7.555193e+06
# mean     1.685862e+00
# std      1.313943e+00
# min      0.000000e+00
# 25%      8.400000e-01
# 50%      1.310000e+00
# 75%      2.110000e+00
# max      8.816000e+01
# Name: sales_tax, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_20_01, y="sales_tax");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## congestion_surcharge

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.congestion_surcharge.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"La descripción de cada mes es: "
          f"{df.congestion_surcharge.describe()}\n")
# Out:
# La descripción de cada mes es: count    2.056937e+07
# mean     9.744287e-01
# std      1.261104e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      8.250000e+00
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    2.172510e+07
# mean     1.000773e+00
# std      1.270717e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      8.250000e+00
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    1.339293e+07
# mean     8.436457e-01
# std      1.227085e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      8.250000e+00
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    4.312909e+06
# mean     5.780185e-01
# std      1.120517e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.500000e+00
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    6.089999e+06
# mean     6.133130e-01
# std      1.144835e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.500000e+00
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    7.555193e+06
# mean     6.854958e-01
# std      1.189792e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.100000e+01
# Name: congestion_surcharge, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_20_01, y="congestion_surcharge");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Se observan outliers por encima del bigote superior. No obstante, dado los valores absolutos, no parecen ser errores.

# %% [markdown]
# ## airport_fee

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.airport_fee.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.9999979095128251
# Promedio de nulos por mes: 0.9999891830187203
# Promedio de nulos por mes: 0.9999982080094808
# Promedio de nulos por mes: 1.0
# Promedio de nulos por mes: 0.999982922821498
# Promedio de nulos por mes: 0.9999994705628301

# %% [markdown]
# Hay un promedio de nulos superior al 99%.

# %%
for df in tlc_20_S1:
    print(f"La descripción de cada mes es: "
          f"{df.airport_fee.describe()}\n")
# Out:
# La descripción de cada mes es: count    43.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: airport_fee, dtype: float64
#
# La descripción de cada mes es: count    235.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: airport_fee, dtype: float64
#
# La descripción de cada mes es: count    24.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: airport_fee, dtype: float64
#
# La descripción de cada mes es: count     0.0
# mean     <NA>
# std      <NA>
# min      <NA>
# 25%      <NA>
# 50%      <NA>
# 75%      <NA>
# max      <NA>
# Name: airport_fee, dtype: Float64
#
# La descripción de cada mes es: count    104.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: airport_fee, dtype: float64
#
# La descripción de cada mes es: count    4.0
# mean     0.0
# std      0.0
# min      0.0
# 25%      0.0
# 50%      0.0
# 75%      0.0
# max      0.0
# Name: airport_fee, dtype: float64

# %% [markdown]
# Todos los valores son 0 o nulos.

# %% [markdown]
# ## tips

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.tips.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"La descripción de cada mes es: "
          f"{df.tips.describe()}\n")
# Out:
# La descripción de cada mes es: count    2.056937e+07
# mean     6.074975e-01
# std      2.186553e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+02
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    2.172510e+07
# mean     5.991389e-01
# std      2.150105e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+02
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    1.339293e+07
# mean     5.263801e-01
# std      2.067542e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+02
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    4.312909e+06
# mean     4.481358e-01
# std      2.133796e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.000000e+02
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    6.089999e+06
# mean     4.969315e-01
# std      2.217568e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.640000e+02
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    7.555193e+06
# mean     5.729238e-01
# std      2.201550e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.000000e+02
# Name: tips, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_20_01, y="tips");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## driver_pay

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.driver_pay.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"La descripción de cada mes es: "
          f"{df.driver_pay.describe()}\n")
# Out:
# La descripción de cada mes es: count    2.056937e+07
# mean     1.311404e+01
# std      1.281221e+01
# min     -1.517200e+02
# 25%      5.600000e+00
# 50%      9.610000e+00
# 75%      1.656000e+01
# max      1.054270e+03
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    2.172510e+07
# mean     1.359126e+01
# std      1.288244e+01
# min     -1.710000e+02
# 25%      5.770000e+00
# 50%      1.015000e+01
# 75%      1.725000e+01
# max      4.894620e+03
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    1.339293e+07
# mean     1.368324e+01
# std      1.244444e+01
# min     -2.393300e+02
# 25%      6.120000e+00
# 50%      1.039000e+01
# 75%      1.727000e+01
# max      2.048770e+03
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    4.312909e+06
# mean     1.268058e+01
# std      1.000812e+01
# min     -1.255700e+02
# 25%      6.250000e+00
# 50%      9.880000e+00
# 75%      1.564000e+01
# max      9.309400e+02
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    6.089999e+06
# mean     1.346103e+01
# std      1.058744e+01
# min     -1.184500e+02
# 25%      6.670000e+00
# 50%      1.051000e+01
# 75%      1.665000e+01
# max      9.491800e+02
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    7.555193e+06
# mean     1.553919e+01
# std      1.195893e+01
# min     -1.509500e+02
# 25%      8.000000e+00
# 50%      1.241000e+01
# 75%      1.925000e+01
# max      8.491200e+02
# Name: driver_pay, dtype: float64

# %% [markdown]
# Los valores negativos es probable que sean errores. Haremos un análisis preliminar de outliers.

# %%
sns.boxplot(data = tlc_20_01, y="driver_pay");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## shared_request_flag

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.shared_request_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"Los valores únicos por mes: "
          f"{df.shared_request_flag.unique()}")
# Out:
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']

# %% [markdown]
# Las proporciones de pasajeros que solicitaron compartir viajes fueron:

# %%
for df in tlc_20_S1:
    print(df.shared_request_flag.value_counts(normalize=True), "\n")
# Out:
# shared_request_flag
# N    0.820373
# Y    0.179627
# Name: proportion, dtype: float64
#
# shared_request_flag
# N    0.8325
# Y    0.1675
# Name: proportion, dtype: float64
#
# shared_request_flag
# N    0.869146
# Y    0.130854
# Name: proportion, dtype: float64
#
# shared_request_flag
# N    9.999998e-01
# Y    2.318621e-07
# Name: proportion, dtype: float64
#
# shared_request_flag
# N    9.999992e-01
# Y    8.210182e-07
# Name: proportion, dtype: float64
#
# shared_request_flag
# N    0.99998
# Y    0.00002
# Name: proportion, dtype: float64

# %% [markdown]
# ## shared_match_flag

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.shared_match_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"Los valores únicos por mes: "
          f"{df.shared_match_flag.unique()}")
# Out:
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N']
# Los valores únicos por mes: ['N']
# Los valores únicos por mes: ['N']

# %%
for df in tlc_20_S1:
    print(df.shared_match_flag.value_counts(normalize=True), "\n")
# Out:
# shared_match_flag
# N    0.893886
# Y    0.106114
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    0.896508
# Y    0.103492
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    0.924199
# Y    0.075801
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    1.0
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    1.0
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    1.0
# Name: proportion, dtype: float64

# %% [markdown]
# ## access_a_ride_flag

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.access_a_ride_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"Los valores únicos por mes: "
          f"{df.access_a_ride_flag.unique()}")
# Out:
# Los valores únicos por mes: [' ' 'N']
# Los valores únicos por mes: [' ' 'N']
# Los valores únicos por mes: ['N' ' ']
# Los valores únicos por mes: [' ' 'N']
# Los valores únicos por mes: [' ' 'N']
# Los valores únicos por mes: ['N' ' ']

# %% [markdown]
# Según el diccionario de datos, esta columna puede tomar los valores 'Y' o 'N'. La presencia de un string vacio puede hablar de problemas en la calidad de los datos.

# %% [markdown]
# ## wav_request_flag

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.wav_request_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"Los valores únicos por mes: "
          f"{df.wav_request_flag.unique()}")
# Out:
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']

# %%
for df in tlc_20_S1:
    print(df.wav_request_flag.value_counts(normalize=True), "\n")
# Out:
# wav_request_flag
# N    0.999194
# Y    0.000806
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.999235
# Y    0.000765
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.999157
# Y    0.000843
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.998975
# Y    0.001025
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.998845
# Y    0.001155
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.998566
# Y    0.001434
# Name: proportion, dtype: float64

# %% [markdown]
# En todos los meses, menos del 1% de los pasajeros solicitaron vehículos accesibles para sillas de ruedas.

# %% [markdown]
# ## wav_match_flag

# %%
for df in tlc_20_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.wav_match_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_20_S1:
    print(f"Los valores únicos por mes: "
          f"{df.wav_match_flag.unique()}")
# Out:
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']

# %%
for df in tlc_20_S1:
    print(df.wav_match_flag.value_counts(normalize=True), "\n")
# Out:
# wav_match_flag
# N    0.980072
# Y    0.019928
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.978619
# Y    0.021381
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.973885
# Y    0.026115
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.956615
# Y    0.043385
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.957958
# Y    0.042042
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.954368
# Y    0.045632
# Name: proportion, dtype: float64

# %% [markdown]
# En todos los meses, entre el 1 y el 4% de los viajes sucedieron en vehículos accesibles para sillas de ruedas.
