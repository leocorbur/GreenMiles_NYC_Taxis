# %% [markdown]
# En este archivo haremos un análisis exploratorio preliminar de los viajes de los "High Volume For-Hire Vehicle (HVFHV)" para el __primer semestre__ del año __2022__. Esta categoría empezó a aplicarse en Febrero de 2019 en NYC a vehículos con más de 10000 viajes por día.

# %%
import modin.pandas as pd
from distributed import Client
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# Inicializa un cliente Dask para la ejecución distribuida en múltiples núcleos
client = Client(memory_limit='8GB')

# %%
tlc_22_01 = pd.read_parquet("../raw_data/fhvhv_tripdata_2022-01.parquet")
tlc_22_02 = pd.read_parquet("../raw_data/fhvhv_tripdata_2022-02.parquet")
tlc_22_03 = pd.read_parquet("../raw_data/fhvhv_tripdata_2022-03.parquet")
tlc_22_04 = pd.read_parquet("../raw_data/fhvhv_tripdata_2022-04.parquet")
tlc_22_05 = pd.read_parquet("../raw_data/fhvhv_tripdata_2022-05.parquet")
tlc_22_06 = pd.read_parquet("../raw_data/fhvhv_tripdata_2022-06.parquet")

# %%
# Todos los dataframes del primer semestre de 2022.
tlc_22_S1 = [tlc_22_01, tlc_22_02, tlc_22_03, tlc_22_04, tlc_22_05, tlc_22_06]

# %% [markdown]
# ## Estructura general

# %%
tlc_22_01.dtypes
# Out:
# hvfhs_license_num               object
# dispatching_base_num            object
# originating_base_num            object
# request_datetime        datetime64[ns]
# on_scene_datetime       datetime64[ns]
# pickup_datetime         datetime64[ns]
# dropoff_datetime        datetime64[ns]
# PULocationID                     int64
# DOLocationID                     int64
# trip_miles                     float64
# trip_time                        int64
# base_passenger_fare            float64
# tolls                          float64
# bcf                            float64
# sales_tax                      float64
# congestion_surcharge           float64
# airport_fee                    float64
# tips                           float64
# driver_pay                     float64
# shared_request_flag             object
# shared_match_flag               object
# access_a_ride_flag              object
# wav_request_flag                object
# wav_match_flag                  object
# dtype: object

# %% [markdown]
# Hay 24 columnas:
# * 4 de tipo datetime.
# * 9 de tipo float.
# * 3 de tipo int.
# * 8 de tipo object.

# %%
for df in tlc_22_S1:
    print(f"Filas: {df.shape[0]}")
# Out:
# Filas: 14751591
# Filas: 16019283
# Filas: 18453548
# Filas: 17752561
# Filas: 18157335
# Filas: 17780075

# %%
tlc_22_01.head()
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B03404               B03404
# 1            HV0003               B03404               B03404
# 2            HV0003               B03404               B03404
# 3            HV0003               B03404               B03404
# 4            HV0003               B03404               B03404
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2022-01-01 00:05:31 2022-01-01 00:05:40 2022-01-01 00:07:24
# 1 2022-01-01 00:19:27 2022-01-01 00:22:08 2022-01-01 00:22:32
# 2 2022-01-01 00:43:53 2022-01-01 00:57:37 2022-01-01 00:57:37
# 3 2022-01-01 00:15:36 2022-01-01 00:17:08 2022-01-01 00:18:02
# 4 2022-01-01 00:25:45 2022-01-01 00:26:01 2022-01-01 00:28:01
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  trip_time  \
# 0 2022-01-01 00:18:28           170           161        1.18        664
# 1 2022-01-01 00:30:12           237           161        0.82        460
# 2 2022-01-01 01:07:32           237           161        1.18        595
# 3 2022-01-01 00:23:05           262           229        1.65        303
# 4 2022-01-01 00:35:42           229           141        1.65        461
#
#    base_passenger_fare  tolls   bcf  sales_tax  congestion_surcharge  \
# 0                24.90    0.0  0.75       2.21                  2.75
# 1                11.97    0.0  0.36       1.06                  2.75
# 2                29.82    0.0  0.89       2.65                  2.75
# 3                 7.91    0.0  0.24       0.70                  2.75
# 4                 9.44    0.0  0.28       0.84                  2.75
#
#    airport_fee  tips  driver_pay shared_request_flag shared_match_flag  \
# 0          0.0   0.0       23.03                   N                 N
# 1          0.0   0.0       12.32                   N                 N
# 2          0.0   0.0       23.30                   N                 N
# 3          0.0   0.0        6.30                   N                 N
# 4          0.0   0.0        7.44                   N                 N
#
#   access_a_ride_flag wav_request_flag wav_match_flag
# 0                                   N              N
# 1                                   N              N
# 2                                   N              N
# 3                                   N              N
# 4                                   N              N

# %% [markdown]
# ## Duplicados

# %% [markdown]
# Vamos a analizar la presencia de duplicados. Al haber tantas columnas, vamos a elegir un subset representativo. En caso de encontrar duplicados aplicaremos distintas estrategias.

# %%
#tlc_22_01.duplicated(subset=["pickup_datetime", "dropoff_datetime", 
#                             "PULocationID", "DOLocationID", "trip_miles"]).sum()
# Out:
# 0

# %%
#tlc_22_02.duplicated(subset=["pickup_datetime", "dropoff_datetime", 
#                             "PULocationID", "DOLocationID", "trip_miles"]).sum()
# Out:
# 0

# %%
#tlc_22_03.duplicated(subset=["pickup_datetime", "dropoff_datetime", 
#                             "PULocationID", "DOLocationID", "trip_miles"]).sum()
# Out:
# 0

# %%
#tlc_22_04.duplicated(subset=["pickup_datetime", "dropoff_datetime", 
#                             "PULocationID", "DOLocationID", "trip_miles"]).sum()
# Out:
# 0

# %%
#tlc_22_05.duplicated(subset=["pickup_datetime", "dropoff_datetime", 
#                             "PULocationID", "DOLocationID", "trip_miles"]).sum()
# Out:
# 2075

# %% [markdown]
# Al haber encontrado 2075 duplicados en este subset, analizaremos todo el conjunto de datos.

# %%
#tlc_22_05.duplicated().sum()
# Out:
# 1872

# %% [markdown]
# En efecto, encontramos 1872 duplicados en mayo de 2022.

# %%
#tlc_22_06.duplicated(subset=["pickup_datetime", "dropoff_datetime", 
#                             "PULocationID", "DOLocationID", "trip_miles"]).sum()
# Out:
# 0

# %% [markdown]
# ## hvfhs_license_num

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.hvfhs_license_num.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"Los valores únicos por mes: "
          f"{df.hvfhs_license_num.unique()}")
# Out:
# Los valores únicos por mes: ['HV0003' 'HV0005']
# Los valores únicos por mes: ['HV0003' 'HV0005']
# Los valores únicos por mes: ['HV0003' 'HV0005']
# Los valores únicos por mes: ['HV0003' 'HV0005']
# Los valores únicos por mes: ['HV0003' 'HV0005']
# Los valores únicos por mes: ['HV0003' 'HV0005']

# %%
for df in tlc_22_S1:
    print(df.hvfhs_license_num.value_counts(normalize=True), "\n")
# Out:
# hvfhs_license_num
# HV0003    0.73391
# HV0005    0.26609
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.714195
# HV0005    0.285805
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.711856
# HV0005    0.288144
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.732907
# HV0005    0.267093
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.733887
# HV0005    0.266113
# Name: proportion, dtype: float64
#
# hvfhs_license_num
# HV0003    0.73396
# HV0005    0.26604
# Name: proportion, dtype: float64

# %% [markdown]
# Entre el 71-73% de las licencias corresponden a HV0003 (Uber) mientras que el 26-28% de las licencias restantes corresponden a HV0005 (Lyft).

# %% [markdown]
# ## dispatching_base_num

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.dispatching_base_num.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"Los valores únicos por mes: "
          f"{sorted(df.dispatching_base_num.unique())}")
# Out:
# Los valores únicos por mes: ['B02395', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02835', 'B02864', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02878', 'B02879', 'B02880', 'B02882', 'B02883', 'B02884', 'B02887', 'B02888', 'B02889', 'B03404', 'B03406']
# Los valores únicos por mes: ['B02395', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02835', 'B02864', 'B02865', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02878', 'B02879', 'B02880', 'B02882', 'B02883', 'B02884', 'B02887', 'B02888', 'B02889', 'B03404', 'B03406']
# Los valores únicos por mes: ['B02395', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02835', 'B02864', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02876', 'B02877', 'B02879', 'B02880', 'B02882', 'B02884', 'B02887', 'B02888', 'B02889', 'B03404', 'B03406']
# Los valores únicos por mes: ['B02395', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02835', 'B02864', 'B02866', 'B02867', 'B02869', 'B02870', 'B02871', 'B02872', 'B02876', 'B02877', 'B02880', 'B02882', 'B02884', 'B02887', 'B02888', 'B02889', 'B03404', 'B03406']
# Los valores únicos por mes: ['B02395', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02835', 'B02864', 'B02866', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02880', 'B02882', 'B02884', 'B02887', 'B02888', 'B02889', 'B03404', 'B03406']
# Los valores únicos por mes: ['B02395', 'B02512', 'B02617', 'B02682', 'B02764', 'B02765', 'B02835', 'B02864', 'B02869', 'B02870', 'B02871', 'B02872', 'B02875', 'B02876', 'B02877', 'B02880', 'B02882', 'B02887', 'B02888', 'B02889', 'B03404', 'B03406']

# %% [markdown]
# Cada base está asociada con una compañía distinta.

# %% [markdown]
# ## originating_base_num

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.originating_base_num.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.26586766132548006
# Promedio de nulos por mes: 0.28552395260137425
# Promedio de nulos por mes: 0.2878502822329885
# Promedio de nulos por mes: 0.2668087156551666
# Promedio de nulos por mes: 0.26577132602333986
# Promedio de nulos por mes: 0.2656660334672379

# %% [markdown]
# Hay un promedio de 26-28% de valores faltantes en esta columna.

# %%
for df in tlc_22_S1:
    print(f"Los valores únicos por mes: "
          f"{df.originating_base_num.unique()}")
# Out:
# Los valores únicos por mes: ['B03404' None 'B02764' 'B02395' 'B02889' 'B03406' 'B02878' 'B02867'
#  'B02512' 'B02872' 'B02879' 'B02864' 'B02765' 'B02617' 'B02870' 'B02880'
#  'B02882' 'B03153' 'B02876' 'B02877' 'B02682' 'B02887' 'B02869' 'B02884'
#  'B02026' 'B02888' 'B02866' 'B02875' 'B02835' 'B02871' 'B02883']
# Los valores únicos por mes: ['B03404' None 'B02889' 'B02682' 'B03406' 'B02764' 'B02887' 'B02869'
#  'B02878' 'B02872' 'B02888' 'B02882' 'B02765' 'B02395' 'B02870' 'B02876'
#  'B02884' 'B02864' 'B02867' 'B02835' 'B03153' 'B02877' 'B02871' 'B02026'
#  'B02512' 'B02617' 'B02880' 'B02866' 'B02883' 'B02875' 'B00446' 'B02865'
# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.dropoff_datetime.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"La descripción de cada mes es: "
          f"{df.dropoff_datetime.describe()}\n")
# Out:
# La descripción de cada mes es: count                         14751591
# mean     2022-01-17 01:05:39.393140992
# min                2022-01-01 00:02:49
# 25%                2022-01-09 12:52:39
# 50%                2022-01-17 00:27:14
# 75%                2022-01-24 09:53:59
# max                2022-02-01 07:21:13
# Name: dropoff_datetime, dtype: object
#
# La descripción de cada mes es: count                         16019283
# mean     2022-02-15 06:36:13.446455808
# min                2022-02-01 00:03:21
# 25%         2022-02-08 08:14:39.500000
# 50%                2022-02-15 03:57:24
# 75%         2022-02-22 08:10:30.500000
# max                2022-03-01 03:46:39
# Name: dropoff_datetime, dtype: object
#
# La descripción de cada mes es: count                         18453548
# mean     2022-03-16 14:50:56.415932928
# min                2022-03-01 00:02:18
# 25%                2022-03-08 23:11:21
# 50%                2022-03-16 17:21:48
# 75%                2022-03-24 13:55:24
# max                2022-04-01 04:00:02
# Name: dropoff_datetime, dtype: object
#
# La descripción de cada mes es: count                         17752561
# mean     2022-04-16 00:08:21.018445824
# min                2022-04-01 00:02:17
# 25%                2022-04-08 11:14:46
# 50%                2022-04-15 21:07:16
# 75%                2022-04-23 15:44:35
# max                2022-05-01 03:21:29
# Name: dropoff_datetime, dtype: object
#
# La descripción de cada mes es: count                         18157335
# mean     2022-05-16 11:13:42.581826816
# min                2022-05-01 00:02:34
# 25%                2022-05-08 15:10:48
# 50%                2022-05-16 08:42:40
# 75%                2022-05-23 19:59:24
# max                2022-06-01 04:26:03
# Name: dropoff_datetime, dtype: object
#
# La descripción de cada mes es: count                         17780075
# mean     2022-06-15 23:33:22.240231168
# min                2022-06-01 00:02:31
# 25%         2022-06-08 17:28:16.500000
# 50%                2022-06-15 23:58:43
# 75%                2022-06-23 13:59:23
# max                2022-07-01 04:03:46
# Name: dropoff_datetime, dtype: object

# %% [markdown]
# No se observan outliers. Los valores extremos se superponen entre meses en algunos casos.

# %% [markdown]
# ## PULocationID

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.PULocationID.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"El número de zonas únicas de cada mes es: "
          f"{df.PULocationID.nunique()}")
# Out:
# El número de zonas únicas de cada mes es: 260
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 263
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 261

# %% [markdown]
# Es la zona de taxi TLC donde inició el viaje. Hay 265 en total.

# %%
for df in tlc_22_S1:
    print(f"Mínimo: {df.PULocationID.min()}, Máximo {df.PULocationID.max()}")
# Out:
# Mínimo: 2, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 2, Máximo 265

# %% [markdown]
# No se observan outliers en esta columna.

# %% [markdown]
# ## DOLocationID

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.DOLocationID.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"El número de zonas únicas de cada mes es: "
          f"{df.DOLocationID.nunique()}")
# Out:
# El número de zonas únicas de cada mes es: 261
# El número de zonas únicas de cada mes es: 261
# El número de zonas únicas de cada mes es: 261
# El número de zonas únicas de cada mes es: 261
# El número de zonas únicas de cada mes es: 262
# El número de zonas únicas de cada mes es: 262

# %% [markdown]
# Es la zona de taxi TLC donde culminó el viaje. Hay 265 en total.

# %%
for df in tlc_22_S1:
    print(f"Mínimo: {df.DOLocationID.min()}, Máximo {df.DOLocationID.max()}")
# Out:
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265
# Mínimo: 1, Máximo 265

# %% [markdown]
# No se observan outliers en esta columna.

# %% [markdown]
# ## trip_miles

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.trip_miles.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"La descripción de cada mes es: "
          f"{df.trip_miles.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.475159e+07
# mean     4.632833e+00
# std      5.312836e+00
# min      0.000000e+00
# 25%      1.520000e+00
# 50%      2.810000e+00
# 75%      5.710000e+00
# max      4.407100e+02
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    1.601928e+07
# mean     4.735295e+00
# std      5.383119e+00
# min      0.000000e+00
# 25%      1.556000e+00
# 50%      2.880000e+00
# 75%      5.850000e+00
# max      4.967100e+02
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    1.845355e+07
# mean     4.915850e+00
# std      5.668483e+00
# min      0.000000e+00
# 25%      1.589000e+00
# 50%      2.960000e+00
# 75%      6.072000e+00
# max      6.287000e+02
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    1.775256e+07
# mean     5.066052e+00
# std      5.827009e+00
# min      0.000000e+00
# 25%      1.640000e+00
# 50%      3.070000e+00
# 75%      6.300000e+00
# max      6.163100e+02
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    1.815734e+07
# mean     5.168193e+00
# std      5.977043e+00
# min      0.000000e+00
# 25%      1.650000e+00
# 50%      3.110000e+00
# 75%      6.450000e+00
# max      4.717300e+02
# Name: trip_miles, dtype: float64
#
# La descripción de cada mes es: count    1.778008e+07
# mean     5.169061e+00
# std      6.058429e+00
# min      0.000000e+00
# 25%      1.660000e+00
# 50%      3.119000e+00
# 75%      6.420000e+00
# max      6.259600e+02
# Name: trip_miles, dtype: float64

# %% [markdown]
# Las distancias de 0 millas parecen ser errores. Veamos algunos ejemplos.

# %%
tlc_22_01[tlc_22_01.trip_miles == 0].head()
# Out:
#       hvfhs_license_num dispatching_base_num originating_base_num  \
# 6860             HV0003               B03404               B03404
# 9843             HV0003               B03404               B03404
# 11155            HV0003               B03404               B03404
# 14012            HV0003               B03404               B03404
# 14024            HV0003               B03404               B03404
#
#          request_datetime   on_scene_datetime     pickup_datetime  \
# 6860  2021-12-31 23:30:58 2022-01-01 00:04:38 2022-01-01 00:04:38
# 9843  2022-01-01 00:19:20 2022-01-01 00:25:06 2022-01-01 00:31:10
# 11155 2022-01-01 00:24:27 2022-01-01 00:25:52 2022-01-01 00:25:52
# 14012 2022-01-01 00:12:42 2022-01-01 00:12:53 2022-01-01 00:12:53
# 14024 2022-01-01 00:44:41 2022-01-01 00:49:55 2022-01-01 00:51:55
#
#          dropoff_datetime  PULocationID  DOLocationID  trip_miles  ...  \
# 6860  2022-01-01 00:05:40           161           161         0.0  ...
# 9843  2022-01-01 00:35:13           210           210         0.0  ...
# 11155 2022-01-01 00:28:07            48            48         0.0  ...
# 14012 2022-01-01 00:13:49           174           174         0.0  ...
# 14024 2022-01-01 00:57:32             4             4         0.0  ...
#
#        sales_tax  congestion_surcharge  airport_fee  tips  driver_pay  \
# 6860        0.70                  2.75          0.0   0.0        7.97
# 9843        0.88                  0.00          0.0   0.0        0.00
# 11155       0.92                  2.75          0.0   0.0        7.23
# 14012       0.64                  0.00          0.0   0.0        7.60
# 14024       1.00                  2.75          0.0   0.0        8.83
#
#        shared_request_flag shared_match_flag access_a_ride_flag  \
# 6860                     N                 N
# 9843                     N                 N
# 11155                    N                 N
# 14012                    N                 N
# 14024                    N                 N
#
#       wav_request_flag wav_match_flag
# 6860                 N              N
# 9843                 N              N
# 11155                N              N
# 14012                N              Y
# 14024                N              N
#
# [5 rows x 24 columns]

# %% [markdown]
# Vemos que en general son viajes cortos, dentro del mismo burough. Pueden ser errores o pueden ser viajes menores a 0,1 millas (160 m). Vamos a analizar outliers.

# %%
sns.boxplot(data = tlc_22_01, y="trip_miles");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Se observan numerosos outliers por este método. Quedará determinar si corresponde a errores o es debido a la dispersión de los datos. La superficie de NYC es de aproximadamente 468 millas cuadradas.

# %% [markdown]
# ## trip_time

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.trip_time.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"La descripción de cada mes es: "
          f"{df.trip_time.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.475159e+07
# mean     1.020126e+03
# std      6.874427e+02
# min      0.000000e+00
# 25%      5.490000e+02
# 50%      8.510000e+02
# 75%      1.303000e+03
# max      1.479180e+05
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    1.601928e+07
# mean     1.104385e+03
# std      7.632796e+02
# min      0.000000e+00
# 25%      5.790000e+02
# 50%      9.110000e+02
# 75%      1.412000e+03
# max      9.858900e+04
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    1.845355e+07
# mean     1.133107e+03
# std      7.871693e+02
# min      1.000000e+00
# 25%      5.910000e+02
# 50%      9.330000e+02
# 75%      1.449000e+03
# max      4.987500e+04
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    1.775256e+07
# mean     1.161346e+03
# std      8.214458e+02
# min      0.000000e+00
# 25%      6.000000e+02
# 50%      9.510000e+02
# 75%      1.482000e+03
# max      4.329800e+04
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    1.815734e+07
# mean     1.205217e+03
# std      8.801463e+02
# min      0.000000e+00
# 25%      6.110000e+02
# 50%      9.740000e+02
# 75%      1.533000e+03
# max      6.827100e+04
# Name: trip_time, dtype: float64
#
# La descripción de cada mes es: count    1.778008e+07
# mean     1.216133e+03
# std      8.924502e+02
# min      0.000000e+00
# 25%      6.180000e+02
# 50%      9.840000e+02
# 75%      1.544000e+03
# max      4.230900e+04
# Name: trip_time, dtype: float64

# %% [markdown]
# Tiempos de viaje de 0 segundos podrían ser errores. Veamos algunos casos.

# %%
tlc_22_01[tlc_22_01.trip_time == 0].head()
# Out:
#          hvfhs_license_num dispatching_base_num originating_base_num  \
# 10279851            HV0003               B03404               B03404
#
#             request_datetime   on_scene_datetime     pickup_datetime  \
# 10279851 2022-01-22 20:39:50 2022-01-22 20:40:23 2022-01-22 20:40:23
#
#             dropoff_datetime  PULocationID  DOLocationID  trip_miles  \
# 10279851 2022-01-22 20:40:23           146           146        0.01
#
#           trip_time  base_passenger_fare  tolls   bcf  sales_tax  \
# 10279851          0                 7.19    0.0  0.22       0.64
#
#           congestion_surcharge  airport_fee  tips  driver_pay  \
# 10279851                   0.0          0.0   0.0         0.0
#
#          shared_request_flag shared_match_flag access_a_ride_flag  \
# 10279851                   N                 N
#
#          wav_request_flag wav_match_flag
# 10279851                N              N

# %% [markdown]
# Hay solo 5 casos en el primer semestre de 2022. Y el pickup_time coincide con el dropoff_time, por lo que es factible que se trate de errores. Hagamos un análisis preliminar de outliers.

# %%
sns.boxplot(data = tlc_22_01, y="trip_time");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# También se observan numerosos outliers que corresponderá estudiar. Probablemente aquellos en el orden de 140000 segundos (aprox. 39 horas) sean errores.

# %% [markdown]
# ## base_passenger_fare

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.base_passenger_fare.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"La descripción de cada mes es: "
          f"{df.base_passenger_fare.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.475159e+07
# mean     1.965113e+01
# std      1.546124e+01
# min     -3.486100e+02
# 25%      9.860000e+00
# 50%      1.541000e+01
# 75%      2.400000e+01
# max      4.995960e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    1.601928e+07
# mean     2.111823e+01
# std      1.642853e+01
# min     -5.201100e+02
# 25%      1.068000e+01
# 50%      1.679000e+01
# 75%      2.593000e+01
# max      2.024730e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    1.845355e+07
# mean     2.245641e+01
# std      1.813076e+01
# min     -5.012500e+02
# 25%      1.120000e+01
# 50%      1.745000e+01
# 75%      2.751000e+01
# max      3.356700e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    1.775256e+07
# mean     2.406397e+01
# std      1.949136e+01
# min     -5.108200e+02
# 25%      1.187000e+01
# 50%      1.883000e+01
# 75%      2.976000e+01
# max      3.732900e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    1.815734e+07
# mean     2.558900e+01
# std      2.105190e+01
# min     -3.252800e+02
# 25%      1.242000e+01
# 50%      1.978000e+01
# 75%      3.157000e+01
# max      2.493860e+03
# Name: base_passenger_fare, dtype: float64
#
# La descripción de cada mes es: count    1.778008e+07
# mean     2.507782e+01
# std      2.111751e+01
# min     -1.055700e+02
# 25%      1.191000e+01
# 50%      1.922000e+01
# 75%      3.084000e+01
# max      2.409230e+03
# Name: base_passenger_fare, dtype: float64

# %% [markdown]
# Las tarifas negativas probablemente sean errores. Aquellas tarifas en el orden de 10^3, también es posible que sean errores, por alejarse del resto de los cuartilos. Hagamos un análisis preliminar de outliers.

# %%
sns.boxplot(data = tlc_22_01, y="base_passenger_fare");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Se observan numerosos outliers por este método, por lo que corresponderá revisar si corresponden a errores en los datos o no.

# %% [markdown]
# ## tolls

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.tolls.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"La descripción de cada mes es: "
          f"{df.tolls.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.475159e+07
# mean     8.979449e-01
# std      3.414747e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.045800e+02
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    1.601928e+07
# mean     9.926226e-01
# std      3.582191e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.353200e+02
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    1.845355e+07
# mean     1.080624e+00
# std      3.727734e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      4.413600e+02
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    1.775256e+07
# mean     1.128932e+00
# std      3.810842e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.623300e+02
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    1.815734e+07
# mean     1.182228e+00
# std      3.935689e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.200000e+02
# Name: tolls, dtype: float64
#
# La descripción de cada mes es: count    1.778008e+07
# mean     1.194475e+00
# std      3.975068e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.262000e+02
# Name: tolls, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_22_01, y="tolls");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## bcf

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.bcf.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"La descripción de cada mes es: "
          f"{df.bcf.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.475159e+07
# mean     6.217636e-01
# std      5.278451e-01
# min      0.000000e+00
# 25%      3.000000e-01
# 50%      4.700000e-01
# 75%      7.400000e-01
# max      1.645600e+02
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    1.601928e+07
# mean     6.671241e-01
# std      5.589842e-01
# min      0.000000e+00
# 25%      3.200000e-01
# 50%      5.100000e-01
# 75%      8.100000e-01
# max      9.721000e+01
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    1.845355e+07
# mean     7.115143e-01
# std      6.144951e-01
# min      0.000000e+00
# 25%      3.400000e-01
# 50%      5.300000e-01
# 75%      8.600000e-01
# max      1.015000e+02
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    1.775256e+07
# mean     7.615644e-01
# std      6.583965e-01
# min      0.000000e+00
# 25%      3.600000e-01
# 50%      5.700000e-01
# 75%      9.300000e-01
# max      1.125400e+02
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    1.815734e+07
# mean     8.075211e-01
# std      7.046468e-01
# min      0.000000e+00
# 25%      3.700000e-01
# 50%      6.000000e-01
# 75%      9.900000e-01
# max      8.395000e+01
# Name: bcf, dtype: float64
#
# La descripción de cada mes es: count    1.778008e+07
# mean     7.946835e-01
# std      7.077042e-01
# min      0.000000e+00
# 25%      3.600000e-01
# 50%      5.800000e-01
# 75%      9.700000e-01
# max      7.291000e+01
# Name: bcf, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_22_01, y="bcf");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## sales_tax

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.sales_tax.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"La descripción de cada mes es: "
          f"{df.sales_tax.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.475159e+07
# mean     1.707564e+00
# std      1.321465e+00
# min      0.000000e+00
# 25%      8.500000e-01
# 50%      1.340000e+00
# 75%      2.110000e+00
# max      4.868300e+02
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    1.601928e+07
# mean     1.820186e+00
# std      1.402277e+00
# min      0.000000e+00
# 25%      9.000000e-01
# 50%      1.440000e+00
# 75%      2.270000e+00
# max      2.875800e+02
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    1.845355e+07
# mean     1.922551e+00
# std      1.520730e+00
# min      0.000000e+00
# 25%      9.500000e-01
# 50%      1.500000e+00
# 75%      2.390000e+00
# max      2.468400e+02
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    1.775256e+07
# mean     2.052402e+00
# std      1.630296e+00
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      1.610000e+00
# 75%      2.600000e+00
# max      3.329400e+02
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    1.815734e+07
# mean     2.167914e+00
# std      1.757625e+00
# min      0.000000e+00
# 25%      1.030000e+00
# 50%      1.680000e+00
# 75%      2.740000e+00
# max      2.283800e+02
# Name: sales_tax, dtype: float64
#
# La descripción de cada mes es: count    1.778008e+07
# mean     2.124014e+00
# std      1.757838e+00
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      1.640000e+00
# 75%      2.670000e+00
# max      2.156800e+02
# Name: sales_tax, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_22_01, y="sales_tax");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## congestion_surcharge

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.congestion_surcharge.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"La descripción de cada mes es: "
          f"{df.congestion_surcharge.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.475159e+07
# mean     1.079914e+00
# std      1.351230e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      1.100000e+01
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    1.601928e+07
# mean     1.160580e+00
# std      1.371841e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      8.250000e+00
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    1.845355e+07
# mean     1.150462e+00
# std      1.359441e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      1.100000e+01
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    1.775256e+07
# mean     1.166918e+00
# std      1.361159e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      1.100000e+01
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    1.815734e+07
# mean     1.162459e+00
# std      1.368854e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      1.100000e+01
# Name: congestion_surcharge, dtype: float64
#
# La descripción de cada mes es: count    1.778008e+07
# mean     1.160395e+00
# std      1.366686e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.750000e+00
# max      1.100000e+01
# Name: congestion_surcharge, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_22_01, y="congestion_surcharge");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Se observan outliers por encima del bigote superior. No obstante, dado los valores absolutos, no parecen ser errores.

# %% [markdown]
# ## airport_fee

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.airport_fee.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"La descripción de cada mes es: "
          f"{df.airport_fee.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.475159e+07
# mean     1.470887e-01
# std      5.920917e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      6.400000e+00
# Name: airport_fee, dtype: float64
#
# La descripción de cada mes es: count    1.601928e+07
# mean     1.542164e-01
# std      6.045528e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      6.400000e+00
# Name: airport_fee, dtype: float64
#
# La descripción de cada mes es: count    1.845355e+07
# mean     1.822664e-01
# std      6.537316e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      6.900000e+00
# Name: airport_fee, dtype: float64
#
# La descripción de cada mes es: count    1.775256e+07
# mean     1.977550e-01
# std      6.814153e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      7.500000e+00
# Name: airport_fee, dtype: float64
#
# La descripción de cada mes es: count    1.815734e+07
# mean     2.190424e-01
# std      7.118799e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      6.900000e+00
# Name: airport_fee, dtype: float64
#
# La descripción de cada mes es: count    1.778008e+07
# mean     2.122203e-01
# std      7.030242e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      6.900000e+00
# Name: airport_fee, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_22_01, y="airport_fee");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Se observan outliers por encima del bigote superior. No obstante, dado los valores absolutos, no parecen ser errores.

# %% [markdown]
# ## tips

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.tips.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"La descripción de cada mes es: "
          f"{df.tips.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.475159e+07
# mean     8.065149e-01
# std      2.448188e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.031600e+02
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    1.601928e+07
# mean     8.910467e-01
# std      2.588551e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.000000e+02
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    1.845355e+07
# mean     1.005846e+00
# std      2.840926e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.700000e+02
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    1.775256e+07
# mean     1.112949e+00
# std      3.060867e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.670000e+02
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    1.815734e+07
# mean     1.166654e+00
# std      3.234773e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.942200e+02
# Name: tips, dtype: float64
#
# La descripción de cada mes es: count    1.778008e+07
# mean     1.164189e+00
# std      3.247914e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.500000e+02
# Name: tips, dtype: float64

# %% [markdown]
# Los valores mínimos de 0 son factibles. Hagamos un análisis preliminar de outliers para ver los superiores.

# %%
sns.boxplot(data = tlc_22_01, y="tips");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## driver_pay

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.driver_pay.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"La descripción de cada mes es: "
          f"{df.driver_pay.describe()}\n")
# Out:
# La descripción de cada mes es: count    1.475159e+07
# mean     1.563843e+01
# std      1.231398e+01
# min     -1.826400e+02
# 25%      7.680000e+00
# 50%      1.203000e+01
# 75%      1.941000e+01
# max      4.643190e+03
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    1.601928e+07
# mean     1.643209e+01
# std      1.309580e+01
# min     -1.910000e+02
# 25%      7.820000e+00
# 50%      1.265000e+01
# 75%      2.053000e+01
# max      1.707760e+03
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    1.845355e+07
# mean     1.807682e+01
# std      1.445710e+01
# min     -5.454000e+01
# 25%      8.720000e+00
# 50%      1.392000e+01
# 75%      2.248000e+01
# max      2.006460e+03
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    1.775256e+07
# mean     1.902645e+01
# std      1.530752e+01
# min     -1.778000e+01
# 25%      9.070000e+00
# 50%      1.481000e+01
# 75%      2.392000e+01
# max      2.053100e+03
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    1.815734e+07
# mean     2.016882e+01
# std      1.612831e+01
# min     -1.244800e+02
# 25%      9.680000e+00
# 50%      1.575000e+01
# 75%      2.527000e+01
# max      1.838600e+03
# Name: driver_pay, dtype: float64
#
# La descripción de cada mes es: count    1.778008e+07
# mean     1.992252e+01
# std      1.629283e+01
# min     -1.300000e+02
# 25%      9.570000e+00
# 50%      1.536000e+01
# 75%      2.477000e+01
# max      9.933100e+02
# Name: driver_pay, dtype: float64

# %% [markdown]
# Los valores negativos es probable que sean errores. Haremos un análisis preliminar de outliers.

# %%
sns.boxplot(data = tlc_22_01, y="driver_pay");
# Out:
# FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Según este método, hay outliers por encima del bigote superior. Queda determinar si son errores o se deben a la distribución de los datos.

# %% [markdown]
# ## shared_request_flag

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.shared_request_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"Los valores únicos por mes: "
          f"{df.shared_request_flag.unique()}")
# Out:
# Los valores únicos por mes: ['N']
# Los valores únicos por mes: ['N']
# Los valores únicos por mes: ['N']
# Los valores únicos por mes: ['N']
# Los valores únicos por mes: ['N']
# Los valores únicos por mes: ['N' 'Y']

# %% [markdown]
# En los primeros 5 meses del 2022, ningún pasajero solicitó compartir viaje. En junio de 2022, la proporción fue:

# %%
tlc_22_06.shared_request_flag.value_counts(normalize=True)
# Out:
# shared_request_flag
# N    0.997599
# Y    0.002401
# Name: proportion, dtype: float64

# %% [markdown]
# ## shared_match_flag

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.shared_match_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"Los valores únicos por mes: "
          f"{df.shared_match_flag.unique()}")
# Out:
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']

# %%
for df in tlc_22_S1:
    print(df.shared_match_flag.value_counts(normalize=True), "\n")
# Out:
# shared_match_flag
# N    0.999861
# Y    0.000139
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    0.999791
# Y    0.000209
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    0.999904
# Y    0.000096
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    0.999576
# Y    0.000424
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    0.999748
# Y    0.000252
# Name: proportion, dtype: float64
#
# shared_match_flag
# N    0.999497
# Y    0.000503
# Name: proportion, dtype: float64

# %% [markdown]
# En todos los meses, menos del 1% de los pasajeros compartieron viajes.

# %% [markdown]
# ## access_a_ride_flag

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.access_a_ride_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"Los valores únicos por mes: "
          f"{df.access_a_ride_flag.unique()}")
# Out:
# Los valores únicos por mes: [' ' 'N']
# Los valores únicos por mes: [' ' 'N']
# Los valores únicos por mes: [' ' 'N']
# Los valores únicos por mes: [' ' 'N']
# Los valores únicos por mes: [' ' 'N']
# Los valores únicos por mes: [' ' 'N']

# %% [markdown]
# Según el diccionario de datos, esta columna puede tomar los valores 'Y' o 'N'. La presencia de un string vacio puede hablar de problemas en la calidad de los datos.

# %% [markdown]
# ## wav_request_flag

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.wav_request_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"Los valores únicos por mes: "
          f"{df.wav_request_flag.unique()}")
# Out:
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']

# %%
for df in tlc_22_S1:
    print(df.wav_request_flag.value_counts(normalize=True), "\n")
# Out:
# wav_request_flag
# N    0.998947
# Y    0.001053
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.998904
# Y    0.001096
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.998723
# Y    0.001277
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.998774
# Y    0.001226
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.998768
# Y    0.001232
# Name: proportion, dtype: float64
#
# wav_request_flag
# N    0.998734
# Y    0.001266
# Name: proportion, dtype: float64

# %% [markdown]
# En todos los meses, menos del 1% de los pasajeros solicitaron vehículos accesibles para sillas de ruedas.

# %% [markdown]
# ## wav_match_flag

# %%
for df in tlc_22_S1:
    print(f"Promedio de nulos por mes: "
          f"{df.wav_match_flag.isna().mean()}")
# Out:
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0
# Promedio de nulos por mes: 0.0

# %%
for df in tlc_22_S1:
    print(f"Los valores únicos por mes: "
          f"{df.wav_match_flag.unique()}")
# Out:
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']
# Los valores únicos por mes: ['N' 'Y']

# %%
for df in tlc_22_S1:
    print(df.wav_match_flag.value_counts(normalize=True), "\n")
# Out:
# wav_match_flag
# N    0.947551
# Y    0.052449
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.945698
# Y    0.054302
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.947841
# Y    0.052159
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.953088
# Y    0.046912
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.940603
# Y    0.059397
# Name: proportion, dtype: float64
#
# wav_match_flag
# N    0.939914
# Y    0.060086
# Name: proportion, dtype: float64

# %% [markdown]
# En todos los meses, entre el 4 y el 6% de los viajes sucedieron en vehículos accesibles para sillas de ruedas.
